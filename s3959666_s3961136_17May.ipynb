# %% [markdown]
# # Project 1: Classify Images of Road Traffic Signs

# %% [markdown]
# ### Objective
# -  Identify and classify images of road traffic signs to enhance navigation systems and improve road safety

# %% [markdown]
# ### **Dataset**

# %% [markdown]
# Source: Belgium Traffic Sign Classification Benchmark, German TSC dataset
#
# Input variables:
#
# Output variable (desired target):

# %% [markdown]
# # Table of Contents
# * 1. Import Libraries
# * 2. Process the dataset
# * 3. Exploratory Data Analysis (EDA)
#   - 3.1 Visualise sample images according to shape and type
#   - 3.2 Data Distribution
# * 4. Data Splitting
# * 5. Data Modelling
#   - 5.1 Baseline Model: MLP NN
#     - Model 1.1: Shape classification using MLP NN
#     - Model 1.2: Type classification using MLP NN
#   - 5.2 Transfer to CNN Model
#     - Model 2.1: Shape classification (converting model 1.1 into CNN)
#     - Model 2.2: Type classification (converting model 1.2 into CNN)
#   - 5.3 Advanced Model: VGG
#     - Model 3.1: Shape classification using VGG
#     - Model 3.2: Type
# classification using CNN
#   - Data Augmentation
# * 6. Testing the model
# * 7. Conclusion
# * 8. Reference

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import itertools
from sklearn.metrics import confusion_matrix, f1_score
from imblearn.over_sampling import SMOTE
import cv2
import tensorflow as tf

# show better graph
# %matplotlib inline

# %%
from google.colab import drive
drive .mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### Connect to the dataset file from google drive

# %%
# !cp /content/drive/'My Drive'/Assignment2/trafficsigns_dataset.zip .
# !cp /content/drive/'My Drive'/Assignment2/trafficsigns_dataset_testing.zip .

# !cp /content/drive/'My Drive'/COSC2673/Assignments/Assignment2/trafficsigns_dataset.zip .
# !cp /content/drive/'My Drive'/COSC2673/Assignments/Assignment2/trafficsigns_dataset_testing.zip .

# %% [markdown]
# Unzip the dataset

# %%
import zipfile
with zipfile.ZipFile('trafficsigns_dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('./')
with zipfile.ZipFile('trafficsigns_dataset_testing.zip', 'r') as zip_ref_test:
    zip_ref_test.extractall('./')

# %% [markdown]
# ## 2. Process the dataset
# Collect Image Files
# - Function to traverse directories recursively and collect image files from the offered dataset and additional dataset for testing

# %%
def collect_image_files(directory):
    image_files = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith('.jpg') or file.endswith('.png'):
                image_files.append(os.path.join(root, file))
    return image_files

# %%
all_image_files = collect_image_files('./trafficsigns_dataset')
all_test_image = collect_image_files('./trafficsigns_dataset_testing')

# %% [markdown]
# Create a DataFrame with image file paths in a column named 'image_path'

# %%
df = pd.DataFrame({'image_path': all_image_files})
df_test = pd.DataFrame({'image_path': all_test_image})

# %% [markdown]
# To encode the traffic sign shapes and types

# %%
trafficsigns_shapes = {'diamond': 0, 'hex': 1, 'round': 2, 'square': 3, 'triangle': 4}
trafficsigns_types = {'rightofway': 0, 'stop': 1, 'bicycle': 2, 'limitedtraffic': 3, 'noentry': 4, 'noparking': 5,
                      'roundabout':6, 'speed': 7, 'trafficdirective': 8, 'traveldirection': 9, 'continue': 10,
                      'crossing': 11,  'laneend': 12, 'parking': 13, 'giveway': 14, 'warning': 15}

# %% [markdown]
# This project involves **multi-class image classification** and features traffic signs categorised into 5 shape classes and 16 type classes, with each image being classified into one of these categories

# %%
def assign_class_label(image_path):
    # Split the image path by '/'
    parts = image_path.split('/')

    # Extract shape and type from the parts
    shape = parts[-3]
    trafficsign_type = parts[-2]

    # Map shape and type to corresponding class labels using the dictionaries
    shape_label = trafficsigns_shapes.get(shape, -1)  # -1 if shape not found in dictionary
    type_label = trafficsigns_types.get(trafficsign_type, -1)  # -1 if type not found in dictionary

    # Return a tuple of shape label and type label
    return (shape_label, type_label)

# %% [markdown]
# - Get the dataframe with image_path, shape_label and type_label

# %%
df['shape_label'], df['type_label'] = zip(*df['image_path'].apply(assign_class_label))
df_test['shape_label'], df_test['type_label'] = zip(*df_test['image_path'].apply(assign_class_label))

# %%
print(f"Shape of offered dataset: {df.shape}.\n Shape of additional dataset: {df_test.shape}")
# Out:
# Shape of offered dataset: (3699, 3).
#  Shape of additional dataset: (2234, 3)

# %%
df.head()
# Out:
#                                           image_path  shape_label  type_label
# 0  ./trafficsigns_dataset/triangle/giveway/01368_...            4          14
# 1  ./trafficsigns_dataset/triangle/giveway/01203_...            4          14
# 2  ./trafficsigns_dataset/triangle/giveway/01829_...            4          14
# 3  ./trafficsigns_dataset/triangle/giveway/00610_...            4          14
# 4  ./trafficsigns_dataset/triangle/giveway/00056_...            4          14

# %%
df_test.head()
# Out:
#                                           image_path  shape_label  type_label
# 0  ./trafficsigns_dataset_testing/triangle/givewa...            4          14
# 1  ./trafficsigns_dataset_testing/triangle/givewa...            4          14
# 2  ./trafficsigns_dataset_testing/triangle/givewa...            4          14
# 3  ./trafficsigns_dataset_testing/triangle/givewa...            4          14
# 4  ./trafficsigns_dataset_testing/triangle/givewa...            4          14

# %% [markdown]
# ## 3. Exploratory Data Analysis (EDA)

# %% [markdown]
# ## 3.1 Visualise sample images according to shape and type

# %%
from matplotlib.pyplot import imread
import imageio


df['class_combo'] = df[['shape_label', 'type_label']].apply(tuple, axis=1)

# Reverse dictionaries to map labels back to names
shape_names = {v: k for k, v in trafficsigns_shapes.items()}
type_names = {v: k for k, v in trafficsigns_types.items()}

# Group by this new combo and pick the first image from each group
grouped = df.groupby('class_combo').first().reset_index()

# Visualization
plt.figure(figsize=(16, 16))
for i, row in enumerate(grouped.itertuples(), 1):
    plt.subplot(4, 4, i)  # Adjust grid size based on the number of unique class combinations
    image_path = os.path.join(os.getcwd(), row.image_path)
    image = imread(image_path)
    # Look up the shape and type names using the reverse dictionaries
    shape_name = shape_names.get(row.shape_label, "Unknown")
    type_name = type_names.get(row.type_label, "Unknown")
    plt.imshow(image)
    plt.axis('off')
    plt.title(f"Shape: {shape_name} ({row.shape_label}), Type: {type_name} ({row.type_label})", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3.2 Distribution of the dataset

# %%
import matplotlib.pyplot as plt


# Convert index to label name for shapes
shape_labels = [f'{k} ({v})' for k, v in sorted(trafficsigns_shapes.items(), key=lambda item: item[1])]
# Convert index to label name for types
type_labels = [f'{k} ({v})' for k, v in sorted(trafficsigns_types.items(), key=lambda item: item[1])]

# Calculate the count of each class label for shape and type
shape_counts = df['shape_label'].value_counts().sort_index()
type_counts = df['type_label'].value_counts().sort_index()

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 5))

# Bar chart for shape labels
axes[0].bar(shape_labels, shape_counts.values, color='#8367c7')
axes[0].set_title('Number of Images per Shape Class')
axes[0].set_xlabel('Shape Class Label')
axes[0].set_ylabel('Number of Images')
axes[0].set_xticklabels(shape_labels, rotation=45, ha='right')
for index, value in enumerate(shape_counts.values):
    axes[0].text(index, value, str(value), ha='center')

# Bar chart for type labels
axes[1].bar(type_labels, type_counts.values, color='#C2F8CB')
axes[1].set_title('Number of Images per Type Class')
axes[1].set_xlabel('Type Class Label')
axes[1].set_ylabel('Number of Images')
axes[1].set_xticklabels(type_labels, rotation=45, ha='right')
for index, value in enumerate(type_counts.values):
    axes[1].text(index, value, str(value), ha='center')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-150-2dc661fc10c5>:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0].set_xticklabels(shape_labels, rotation=45, ha='right')
# <ipython-input-150-2dc661fc10c5>:29: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[1].set_xticklabels(type_labels, rotation=45, ha='right')

# %% [markdown]
# #### Observations:
# - Class imbalance: may affect the model performance. Further actions need to be taken to solve it

# %% [markdown]
# ## 4. Data Spliting
# - split offered dataset into 2 parts.
# - Training set: 80%
# - Validation set: 20%
# - Testing set: the additional dataset

# %% [markdown]
# **Constants**

# %%
# height = 28 pixel, width = 28 pixel, channel = 1 (Grayscale)
INPUT_DIM = (28, 28, 1)
HIDDEN_LAYER_DIM_SHAPE = 128
HIDDEN_LAYER_DIM_TYPE = 256
HIDDEN_LAYER_DIM = 128
OUTPUT_CLASSES_SHAPE = 5  # Number of shape classes
OUTPUT_CLASSES_TYPE = 16  # Number of type classes

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

train_data, val_data = train_test_split(df, test_size=0.2, random_state=42)
test_data = df_test

print("Train data : {}, Val Data: {}, Test Data: {}".format(train_data.shape[0], val_data.shape[0], test_data.shape[0]))
# Out:
# Train data : 2959, Val Data: 740, Test Data: 2234

# %%
train_data.shape
# Out:
# (2959, 4)

# %%
# Print column names to verify
print(train_data.columns)
# Out:
# Index(['image_path', 'shape_label', 'type_label', 'class_combo'], dtype='object')

# %% [markdown]
# ## Solve Class Imbalance with Data Augmentation (SMOTE--Oversampling)

# %% [markdown]
# Prepare data

# %% [markdown]
# #### Define a function to process images

# %%
def get_imgs_array(image_paths):
  images_data = []
  # Load all image
  for img_path in image_paths:
      img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
      images_data.append(img)
  return np.array(images_data)

# %%
X = get_imgs_array(train_data['image_path'])


shape_labels_encoded = train_data['shape_label'].values
type_labels_encoded = train_data['type_label'].values

# Combine shape and type labels into a single multi-label format
# def tuple_to_formatted_string(tup):
#     return f"{tup[0]}_{tup[1]}"

# combined_labels = np.array(train_data['class_combo'].apply(tuple_to_formatted_string))

X_reshape = X.reshape(X.shape[0], -1)

# %% [markdown]
# Initialize SMOTE

# %%
smote = SMOTE(sampling_strategy='auto', random_state=42)

# %% [markdown]
# Oversampling for shape labels

# %%
X_resampled_shape, y_resampled_shape = smote.fit_resample(X_reshape, shape_labels_encoded)
# X_resampled_shape = X_resampled_shape.reshape(X_resampled_shape.shape[0], *original_image_shape)
num_samples = X_resampled_shape.shape[0]
height = 28
width = 28
channel = 1

X_resampled_shape_reshaped = X_resampled_shape.reshape(num_samples, height, width, channel)

# %%
def check_oversampling_classes(resampled_label):
  unique_classes_resampled, counts_resampled = np.unique(resampled_label, return_counts=True)
  print("\nOversampled Class Distribution:")
  for cls, count in zip(unique_classes_resampled, counts_resampled):
      print(f"Class {cls}: {count} samples")

check_oversampling_classes(y_resampled_shape)
# Out:
# Oversampled Class Distribution:
# Class 0: 1414 samples
# Class 1: 1414 samples
# Class 2: 1414 samples
# Class 3: 1414 samples
# Class 4: 1414 samples

# %% [markdown]
# Oversampling for shape and type labels

# %%
X_resampled_shape_type, y_resampled_type = smote.fit_resample(X_reshape, type_labels_encoded)
print(X_resampled_shape_type.shape)
num_samples = X_resampled_shape_type.shape[0]

X_resampled_shape_type = X_resampled_shape_type.reshape(num_samples, height, width, channel)
# Out:
# (8704, 784)

# %%
check_oversampling_classes(y_resampled_type)
# Out:
# Oversampled Class Distribution:
# Class 0: 544 samples
# Class 1: 544 samples
# Class 2: 544 samples
# Class 3: 544 samples
# Class 4: 544 samples
# Class 5: 544 samples
# Class 6: 544 samples
# Class 7: 544 samples
# Class 8: 544 samples
# Class 9: 544 samples
# Class 10: 544 samples
# Class 11: 544 samples
# Class 12: 544 samples
# Class 13: 544 samples
# Class 14: 544 samples
# Class 15: 544 samples

# %% [markdown]
# ## Prepare data for training models

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical


datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')
batch_size = 64

# %% [markdown]
# ##### prepare train data generator

# %%
# function to create image generator
def create_img_generator(x, y, class_num):
  y = to_categorical(y, num_classes=class_num)
  return datagen.flow(x=x, y=y, batch_size=batch_size)


train_generator_shape = create_img_generator(x=X_resampled_shape_reshaped, y=y_resampled_shape, class_num=OUTPUT_CLASSES_SHAPE)

train_generator_type = create_img_generator(x=X_resampled_shape_type, y=y_resampled_type, class_num=OUTPUT_CLASSES_TYPE)

# %% [markdown]
# ##### prepare validation data generator

# %%
def images_for_flow(image_array):
  num_samples = image_array.shape[0]
  return  image_array.reshape(num_samples, 28, 28, 1)

val_x = get_imgs_array(val_data['image_path'])
val_x = images_for_flow(val_x)
val_y_shape = val_data['shape_label']
val_y_type = val_data['type_label']


validation_generator_shape = create_img_generator(x=val_x, y=val_y_shape, class_num=OUTPUT_CLASSES_SHAPE)

validation_generator_type = create_img_generator(x=val_x, y=val_y_type, class_num=OUTPUT_CLASSES_TYPE)

# %%
type(val_y_shape[0])
# Out:
# numpy.int64

# %% [markdown]
# #### Define a function to plot accuracy between validation data and train data

# %%
def plot_learning_curve(train_loss, val_loss, train_metric, val_metric, metric_name='Accuracy'):
    plt.figure(figsize=(10,5))

    plt.subplot(1,2,1)
    plt.plot(train_loss, 'r--')
    plt.plot(val_loss, 'b--')
    plt.xlabel("epochs")
    plt.ylabel("Loss")
    plt.legend(['train', 'val'], loc='upper left')

    plt.subplot(1,2,2)
    plt.plot(train_metric, 'r--')
    plt.plot(val_metric, 'b--')
    plt.xlabel("epochs")
    plt.ylabel(metric_name)
    plt.legend(['train', 'val'], loc='upper left')

# %% [markdown]
# #### Install Keras

# %% [markdown]
# To build an image classifier we make use of Tensorflow‘ s Keras API to build our model

# %%
import tensorflow as tf
AUTOTUNE = tf.data.experimental.AUTOTUNE

tf.__version__
# Out:
# '2.15.0'

# %% [markdown]
# #### Set up the layers
# We will use the Sequential API to build models as it is the simplest. In a **Sequential** type, each layer takes the output from the previous layer and uses it as its input.
# **Dense** layers in a neural network mean that every node in one layer is connected to all the nodes in the previous layer.

# %%
# !pip install visualkeras
# Out:
# Requirement already satisfied: visualkeras in /usr/local/lib/python3.10/dist-packages (0.0.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.25.2)
# Requirement already satisfied: aggdraw>=1.3.11 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.3.18.post0)

# %% [markdown]
# ## 5.1 Base Model - MLP Neural Network (for 2 tasks)

# %% [markdown]
# * **What is an MLP?**
#   - A type of neural network with three or more layers: input, hidden, and output layers.
#   - Fully connected: Each neuron in one layer connects to every neuron in the next layer.
#   - Utilizes backpropagation for learning, adjusting weights to minimize output error.
# * **Why choose an MLP as a baseline model?**
#   - Simplicity: Easy to implement and requires less setup time.
#   - Efficiency: Quick to train, providing fast initial results.
#   - Low Resource Use: Less computationally intensive than more complex models.
#   - Performance Benchmarking: Provides a reference point for evaluating more advanced models.
#   - Data Requirements: Performs well with smaller datasets, ideal when large data is unavailable.
#   - Interpretability: Simple architecture makes it easier to understand and deb

# %% [markdown]
# ### **Model1.1 Baseline Model --- Traffic sign shape**

# %%
model_shape_1 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=INPUT_DIM),
    tf.keras.layers.Dense(units=HIDDEN_LAYER_DIM_SHAPE, activation='relu', name='m1_shape_hidden1'),
    tf.keras.layers.Dense(units=64, activation='relu', name='m1_shape_hidden2'),
    tf.keras.layers.Dense(units=16, activation='relu', name='m1_shape_hidden3'),
    tf.keras.layers.Dense(units=OUTPUT_CLASSES_SHAPE, activation='softmax', name='m1_shape_output')
])

model_shape_1.compile(optimizer='adam',
                loss=tf.keras.losses.CategoricalCrossentropy(),
                metrics=['categorical_accuracy'])

# %%
model_shape_1.summary()
# Out:
# Model: "sequential_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_30 (Flatten)        (None, 784)               0
#
#  m1_shape_hidden1 (Dense)    (None, 128)               100480
#
#  m1_shape_hidden2 (Dense)    (None, 64)                8256
#
#  m1_shape_hidden3 (Dense)    (None, 16)                1040
#
#  m1_shape_output (Dense)     (None, 5)                 85
#
# =================================================================
# Total params: 109861 (429.14 KB)
# Trainable params: 109861 (429.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import visualkeras
# Generating the image for model architecture
visualkeras.layered_view(model_shape_1, scale_xy=2, scale_z=1, max_z=50, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=257x63>

# %%
tf.keras.utils.plot_model(model_shape_1, show_shapes=True)

# %% [markdown]
# #### Train the base model for shape

# %% [markdown]
# train the base model for shape

# %%
history_1_shape = model_shape_1.fit(train_generator_shape, validation_data = validation_generator_shape, epochs=50, verbose=0)

# %%
plot_learning_curve(history_1_shape.history['loss'], history_1_shape.history['val_loss'],
                    history_1_shape.history['categorical_accuracy'], history_1_shape.history['val_categorical_accuracy'],
                    metric_name='Accuracy')

# %% [markdown]
# #### Function to plot **Confusion Matrix** (Will apply this function with final test)

# %%
def plot_confusion_matrix(model, x_set, y_set, nr_classes, label_names):

  predictions = np.argmax(model.predict(x_set / 255.0), axis=1)
  f1score = f1_score(y_set, predictions, average='weighted')
  print(f"F1 Score: {f1score:.2f}")
  accuracy = np.mean(predictions == y_set) * 100
  print(f"Accuracy: {accuracy:.2f}%")
  conf_matrix = confusion_matrix(y_set, predictions)

  nr_rows = conf_matrix.shape[0]
  nr_cols = conf_matrix.shape[1]
  plt.figure(figsize=(7,7), dpi=150)
  plt.imshow(conf_matrix, cmap=plt.cm.Greens)

  plt.title('Confusion Matrix', fontsize=16)
  plt.ylabel('Actual Labels', fontsize=12)
  plt.xlabel('Predicted Labels', fontsize=12)

  tick_marks = np.arange(nr_classes)
  plt.yticks(tick_marks, label_names)
  plt.xticks(tick_marks, label_names, rotation=45, ha='right')

  plt.colorbar()

  for i, j in itertools.product(range(nr_rows), range(nr_cols)):
    plt.text(j, i, conf_matrix[i, j], horizontalalignment='center', color='white' if conf_matrix[i, j] > conf_matrix.max()/2 else 'black')

  plt.show()

# %% [markdown]
# ### use test data plot confusion matrix

# %%
test_x = get_imgs_array(test_data['image_path'])
test_x = images_for_flow(test_x)
test_y_shape = test_data['shape_label']
test_y_type = test_data['type_label']


test_generator_shape = create_img_generator(x=test_x, y=test_y_shape, class_num=OUTPUT_CLASSES_SHAPE)

test_generator_type = create_img_generator(x=test_x, y=test_y_type, class_num=OUTPUT_CLASSES_TYPE)

# %% [markdown]
# #### Here is to test the plot_confusion_matrix function (Will delete)

# %%
model_shape_1.evaluate(test_generator_shape)
# Out:
# 35/35 [==============================] - 0s 5ms/step - loss: 0.1368 - categorical_accuracy: 0.9749
# [0.13683335483074188, 0.974932849407196]

# %%
plot_confusion_matrix(model_shape_1, test_x, test_y_shape, OUTPUT_CLASSES_SHAPE, shape_labels)
# Out:
# 70/70 [==============================] - 0s 2ms/step
# F1 Score: 0.98
# Accuracy: 97.49%

# %% [markdown]
# ### **Model1.2 Baseline Model --- traffic sign type**

# %%
model_type_1 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=INPUT_DIM),
    tf.keras.layers.Dense(units=HIDDEN_LAYER_DIM_TYPE, activation='relu', name='m1_type_hidden1'),
    tf.keras.layers.Dense(units=128, activation='relu', name='m1_type_hidden2'),
    tf.keras.layers.Dense(units=64, activation='relu', name='m1_type_hidden3'),
    tf.keras.layers.Dense(units=OUTPUT_CLASSES_TYPE, activation='softmax', name='m1_output')
])

model_type_1.compile(optimizer='adam',
                loss=tf.keras.losses.CategoricalCrossentropy(),
                metrics=['categorical_accuracy'])

# %%
model_type_1.summary()
# Out:
# Model: "sequential_33"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_31 (Flatten)        (None, 784)               0
#
#  m1_type_hidden1 (Dense)     (None, 256)               200960
#
#  m1_type_hidden2 (Dense)     (None, 128)               32896
#
#  m1_type_hidden3 (Dense)     (None, 64)                8256
#
#  m1_output (Dense)           (None, 16)                1040
#
# =================================================================
# Total params: 243152 (949.81 KB)
# Trainable params: 243152 (949.81 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Generating the image for model architecture
visualkeras.layered_view(model_type_1, scale_xy=2, scale_z=1, max_z=50, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=287x63>

# %%
tf.keras.utils.plot_model(model_type_1, show_shapes=True)

# %% [markdown]
# ### train the base model (type)

# %%
# %%time
history_1_type = model_type_1.fit(train_generator_type, validation_data = validation_generator_type, epochs=50, verbose=0)

# %%
plot_learning_curve(history_1_type.history['loss'], history_1_type.history['val_loss'],
                    history_1_type.history['categorical_accuracy'], history_1_type.history['val_categorical_accuracy'],
                    metric_name='Accuracy')

# %%
model_type_1.evaluate(test_generator_type)
# Out:
# 35/35 [==============================] - 0s 5ms/step - loss: 0.3181 - categorical_accuracy: 0.9490
# [0.31814372539520264, 0.9489704370498657]

# %% [markdown]
# Observations:

# %% [markdown]
# # Model 2 Transfer to CNN model
# - replacing the Flatten layer with convolutional (Conv2D) and pooling (MaxPooling2D) layers.

# %% [markdown]
# #### 1. model to classify shape

# %%
model_shape_2 = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=INPUT_DIM, name='conv1'),
    tf.keras.layers.MaxPooling2D((2, 2), name='pool1'),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', name='conv2'),
    tf.keras.layers.MaxPooling2D((2, 2), name='pool2'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', name='conv3'),
    tf.keras.layers.Flatten(name='flatten'),
    tf.keras.layers.Dense(64, activation='relu', name='dense1'),
    tf.keras.layers.Dense(16, activation='relu', name='dense2'),
    tf.keras.layers.Dense(OUTPUT_CLASSES_SHAPE, activation='softmax', name='output')
])

model_shape_2.compile(optimizer='adam',
                loss=tf.keras.losses.CategoricalCrossentropy(),
                metrics=['categorical_accuracy'])

# %%
model_shape_2.summary()
# Out:
# Model: "sequential_34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 26, 26, 32)        320
#
#  pool1 (MaxPooling2D)        (None, 13, 13, 32)        0
#
#  conv2 (Conv2D)              (None, 11, 11, 64)        18496
#
#  pool2 (MaxPooling2D)        (None, 5, 5, 64)          0
#
#  conv3 (Conv2D)              (None, 3, 3, 128)         73856
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense1 (Dense)              (None, 64)                73792
#
#  dense2 (Dense)              (None, 16)                1040
#
#  output (Dense)              (None, 5)                 85
#
# =================================================================
# Total params: 167589 (654.64 KB)
# Trainable params: 167589 (654.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
visualkeras.layered_view(model_shape_2, scale_xy=2, scale_z=1, max_z=50, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=467x106>

# %%
tf.keras.utils.plot_model(model_shape_2, show_shapes=True)

# %% [markdown]
# ### Fit the model

# %%
history_2_shape = model_shape_2.fit(train_generator_shape, validation_data = validation_generator_shape, epochs=50, verbose=0)

# %%
plot_learning_curve(history_2_shape.history['loss'], history_2_shape.history['val_loss'],
                    history_2_shape.history['categorical_accuracy'], history_2_shape.history['val_categorical_accuracy'],
                    metric_name='Accuracy')

# %%
model_shape_2.evaluate(test_generator_shape)
# Out:
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0325 - categorical_accuracy: 0.9951
# [0.03248831257224083, 0.9950761198997498]

# %% [markdown]
# #### 2. model to classify types

# %%
model_type_2 = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=INPUT_DIM, name='conv1'),
    tf.keras.layers.MaxPooling2D((2, 2), name='pool1'),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', name='conv2'),
    tf.keras.layers.MaxPooling2D((2, 2), name='pool2'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', name='conv3'),
    tf.keras.layers.Flatten(name='flatten'),
    tf.keras.layers.Dense(128, activation='relu', name='dense1'),
    tf.keras.layers.Dense(64, activation='relu', name='dense2'),
    tf.keras.layers.Dense(OUTPUT_CLASSES_TYPE, activation='softmax', name='output')
])

model_type_2.compile(optimizer='adam',
                loss=tf.keras.losses.CategoricalCrossentropy(),
                metrics=['categorical_accuracy'])

# %%
model_type_2.summary()
# Out:
# Model: "sequential_35"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 26, 26, 32)        320
#
#  pool1 (MaxPooling2D)        (None, 13, 13, 32)        0
#
#  conv2 (Conv2D)              (None, 11, 11, 64)        18496
#
#  pool2 (MaxPooling2D)        (None, 5, 5, 64)          0
#
#  conv3 (Conv2D)              (None, 3, 3, 128)         73856
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense1 (Dense)              (None, 128)               147584
#
#  dense2 (Dense)              (None, 64)                8256
#
#  output (Dense)              (None, 16)                1040
#
# =================================================================
# Total params: 249552 (974.81 KB)
# Trainable params: 249552 (974.81 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
visualkeras.layered_view(model_type_2, scale_xy=2, scale_z=1, max_z=50, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=497x106>

# %%
tf.keras.utils.plot_model(model_type_2, show_shapes=True)

# %% [markdown]
# ##### fit the model

# %%
history_2_type = model_type_2.fit(train_generator_type, validation_data = validation_generator_type, epochs=50, verbose=0)

# %%
plot_learning_curve(history_2_type.history['loss'], history_2_type.history['val_loss'],
                    history_2_type.history['categorical_accuracy'], history_2_type.history['val_categorical_accuracy'],
                    metric_name='Accuracy')

# %%
model_type_2.evaluate(test_generator_type)
# Out:
# 35/35 [==============================] - 0s 5ms/step - loss: 0.1238 - categorical_accuracy: 0.9839
# [0.12381938844919205, 0.9838854074478149]

# %%
import matplotlib.pyplot as plt

def plot_combined_learning_curve(shape_history, type_history, metric_name='Accuracy'):
    epochs = range(1, len(shape_history['loss']) + 1)

    plt.figure(figsize=(14, 8))

    # Plot training and validation loss for shape and type
    plt.subplot(1, 2, 1)
    plt.plot(epochs, shape_history['loss'], 'b-', label='Shape Training Loss')
    plt.plot(epochs, shape_history['val_loss'], 'b--', label='Shape Validation Loss')
    plt.plot(epochs, type_history['loss'], 'r-', label='Type Training Loss')
    plt.plot(epochs, type_history['val_loss'], 'r--', label='Type Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # Plot training and validation accuracy for shape and type
    plt.subplot(1, 2, 2)
    plt.plot(epochs, shape_history['categorical_accuracy'], 'b-', label='Shape Training Accuracy')
    plt.plot(epochs, shape_history['val_categorical_accuracy'], 'b--', label='Shape Validation Accuracy')
    plt.plot(epochs, type_history['categorical_accuracy'], 'r-', label='Type Training Accuracy')
    plt.plot(epochs, type_history['val_categorical_accuracy'], 'r--', label='Type Validation Accuracy')
    plt.title(f'Training and Validation {metric_name}')
    plt.xlabel('Epochs')
    plt.ylabel(metric_name)
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# Assuming history_2_shape and history_2_type are available
plot_combined_learning_curve(history_2_shape.history, history_2_type.history, metric_name='Accuracy')

# %% [markdown]
# # 5.2 Advanced Model: CNN model

# %% [markdown]
# CNNs are better suited for tasks like image recognition because they can exploit the spatial structure of the data through convolutional layers, reducing the number of parameters needed compared to fully connected layers in MLPs, making them more efficient and effective for tasks with spatial relationships, like images.

# %% [markdown]
# # VGG

# %% [markdown]
# The VGG architecture enhances basic CNNs through:
# 1. Uniformity: It consistently uses 3×3 convolutional filters and 2×2 max pooling, facilitating deeper network construction.
# 2. Depth: Deeper layers in VGG allow for more complex feature learning, improving image classification performance.
# 3. Robust Training: Strong initialisation, regularisation, and augmentation strategies improve training and prevent overfitting.

# %% [markdown]
# ### Model 2.1 Shape classification using VGG CNN

# %%
model_VGG_1 = tf.keras.Sequential([
    # VGG block 1
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=INPUT_DIM),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D((2, 2)),

    # VGG block 2
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D((2, 2)),

    # VGG block 3
    tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D((2, 2)),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(OUTPUT_CLASSES_SHAPE, activation='softmax'),
])

# %%
model_VGG_1.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['categorical_accuracy'])

# %%
model_VGG_1.summary()
# Out:
# Model: "sequential_36"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_168 (Conv2D)         (None, 28, 28, 64)        640
#
#  conv2d_169 (Conv2D)         (None, 28, 28, 64)        36928
#
#  max_pooling2d_84 (MaxPooli  (None, 14, 14, 64)        0
#  ng2D)
#
#  conv2d_170 (Conv2D)         (None, 14, 14, 128)       73856
#
#  conv2d_171 (Conv2D)         (None, 14, 14, 128)       147584
#
#  max_pooling2d_85 (MaxPooli  (None, 7, 7, 128)         0
#  ng2D)
#
#  conv2d_172 (Conv2D)         (None, 7, 7, 256)         295168
#
#  conv2d_173 (Conv2D)         (None, 7, 7, 256)         590080
#
#  max_pooling2d_86 (MaxPooli  (None, 3, 3, 256)         0
#  ng2D)
#
#  flatten_32 (Flatten)        (None, 2304)              0
#
#  dense_56 (Dense)            (None, 512)               1180160
#
#  dense_57 (Dense)            (None, 5)                 2565
#
# =================================================================
# Total params: 2326981 (8.88 MB)
# Trainable params: 2326981 (8.88 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Generating the image for model architecture
visualkeras.layered_view(model_VGG_1, scale_xy=2, scale_z=1, max_z=50, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=713x111>

# %%
tf.keras.utils.plot_model(model_VGG_1, show_shapes=True)

# %% [markdown]
# Fit the model

# %%
history_VGG_1 = model_VGG_1.fit(
    train_generator_shape,
    validation_data=validation_generator_shape,
    epochs=50,
    verbose=0
)

# %%
plot_learning_curve(history_VGG_1.history['loss'], history_VGG_1.history['val_loss'],
                    history_VGG_1.history['categorical_accuracy'], history_VGG_1.history['val_categorical_accuracy'],
                    metric_name='Accuracy')

# %%
model_VGG_1.evaluate(test_generator_shape)
# Out:
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0358 - categorical_accuracy: 0.9960
# [0.03575068712234497, 0.9959713220596313]

# %% [markdown]
# ### Add Normalisation and Dropout layers

# %% [markdown]
# Justification for Adding Batch Normalization and Dropout:
# * Batch Normalization: Stabilizes and accelerates training, allows higher learning rates, and reduces sensitivity to weight initialization.
# * Dropout: Prevents overfitting and improves generalization by randomly setting a fraction of input units to zero during training.
#
# These additions enhance model stability, speed, and performance on unseen data.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Sequential

def create_model(l2_reg=0.001, dropout_rate=0.3):
    model = Sequential([
        # VGG block 1
        Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=INPUT_DIM, kernel_regularizer=l2(l2_reg)),
        Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(l2_reg)),
        MaxPooling2D((2, 2)),
        BatchNormalization(),
        Dropout(dropout_rate),

        # VGG block 2
        Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(l2_reg)),
        Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(l2_reg)),
        MaxPooling2D((2, 2)),
        BatchNormalization(),
        Dropout(dropout_rate + 0.1),

        # VGG block 3
        Conv2D(256, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(l2_reg)),
        Conv2D(256, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(l2_reg)),
        MaxPooling2D((2, 2)),
        BatchNormalization(),
        Dropout(dropout_rate + 0.1),

        Flatten(),
        Dense(512, activation='relu', kernel_regularizer=l2(l2_reg)),
        BatchNormalization(),
        Dropout(dropout_rate + 0.2),
        Dense(OUTPUT_CLASSES_SHAPE, activation='softmax')
    ])

    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['categorical_accuracy'])
    return model

# Example of different L2 and dropout rates to test
l2_regs = [0.0001, 0.001, 0.01]
dropout_rates = [0.2, 0.3, 0.4]

results = {}

for l2_reg in l2_regs:
    for dropout_rate in dropout_rates:
        print(f'Training with L2={l2_reg} and Dropout={dropout_rate}')
        model = create_model(l2_reg, dropout_rate)
        history = model.fit(train_generator_shape,
                            validation_data=validation_generator_shape,
                            epochs=25,  # Use fewer epochs for quicker experimentation
                            verbose=1)

        val_accuracy = history.history['val_categorical_accuracy'][-1]
        val_loss = history.history['val_loss'][-1]
        results[(l2_reg, dropout_rate)] = (val_accuracy, val_loss)

# Print results
for params, (val_accuracy, val_loss) in results.items():
    print(f'L2={params[0]}, Dropout={params[1]} - Validation Accuracy: {val_accuracy}, Validation Loss: {val_loss}')
# Out:
# Training with L2=0.0001 and Dropout=0.2
# Epoch 1/25
# 111/111 [==============================] - 6s 20ms/step - loss: 0.7437 - categorical_accuracy: 0.8204 - val_loss: 5.7218 - val_categorical_accuracy: 0.2757
# Epoch 2/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.2460 - categorical_accuracy: 0.9734 - val_loss: 8.2610 - val_categorical_accuracy: 0.2770
# Epoch 3/25
# 111/111 [==============================] - 2s 21ms/step - loss: 0.2204 - categorical_accuracy: 0.9833 - val_loss: 1.8493 - val_categorical_accuracy: 0.7649
# Epoch 4/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.1846 - categorical_accuracy: 0.9941 - val_loss: 0.4103 - val_categorical_accuracy: 0.9162
# Epoch 5/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.1832 - categorical_accuracy: 0.9941 - val_loss: 0.3362 - val_categorical_accuracy: 0.9459
# Epoch 6/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.1805 - categorical_accuracy: 0.9934 - val_loss: 0.1897 - val_categorical_accuracy: 0.9959
# Epoch 7/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.1778 - categorical_accuracy: 0.9941 - val_loss: 0.1795 - val_categorical_accuracy: 0.9973
# Epoch 8/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.1684 - categorical_accuracy: 0.9967 - val_loss: 0.1781 - val_categorical_accuracy: 0.9959
# Epoch 9/25
# 111/111 [==============================] - 2s 21ms/step - loss: 0.1650 - categorical_accuracy: 0.9962 - val_loss: 0.1751 - val_categorical_accuracy: 0.9946
# Epoch 10/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.1672 - categorical_accuracy: 0.9952 - val_loss: 0.1804 - val_categorical_accuracy: 0.9919
# Epoch 11/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.1560 - categorical_accuracy: 0.9976 - val_loss: 0.2132 - val_categorical_accuracy: 0.9878
# Epoch 12/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.1478 - categorical_accuracy: 0.9994 - val_loss: 0.2136 - val_categorical_accuracy: 0.9865
# Epoch 13/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.1456 - categorical_accuracy: 0.9986 - val_loss: 0.2000 - val_categorical_accuracy: 0.9824
# Epoch 14/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.1402 - categorical_accuracy: 0.9990 - val_loss: 0.1550 - val_categorical_accuracy: 0.9973
# Epoch 15/25
# 111/111 [==============================] - 2s 21ms/step - loss: 0.1388 - categorical_accuracy: 0.9984 - val_loss: 0.2235 - val_categorical_accuracy: 0.9865
# Epoch 16/25
# 111/111 [==============================] - 2s 19ms/step - loss: 0.1392 - categorical_accuracy: 0.9969 - val_loss: 0.1555 - val_categorical_accuracy: 0.9959
# Epoch 17/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.1507 - categorical_accuracy: 0.9926 - val_loss: 0.2627 - val_categorical_accuracy: 0.9689
# Epoch 18/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.1419 - categorical_accuracy: 0.9959 - val_loss: 0.1575 - val_categorical_accuracy: 0.9959
# Epoch 19/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.1421 - categorical_accuracy: 0.9955 - val_loss: 0.1666 - val_categorical_accuracy: 0.9905
# Epoch 20/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.1314 - categorical_accuracy: 0.9977 - val_loss: 0.1487 - val_categorical_accuracy: 0.9959
# Epoch 21/25
# 111/111 [==============================] - 2s 21ms/step - loss: 0.1220 - categorical_accuracy: 0.9999 - val_loss: 0.1490 - val_categorical_accuracy: 0.9959
# Epoch 22/25
# 111/111 [==============================] - 2s 19ms/step - loss: 0.1182 - categorical_accuracy: 0.9986 - val_loss: 0.1703 - val_categorical_accuracy: 0.9865
# Epoch 23/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.1214 - categorical_accuracy: 0.9969 - val_loss: 0.1699 - val_categorical_accuracy: 0.9838
# Epoch 24/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.1300 - categorical_accuracy: 0.9949 - val_loss: 0.1481 - val_categorical_accuracy: 0.9946
# Epoch 25/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.1229 - categorical_accuracy: 0.9967 - val_loss: 0.1386 - val_categorical_accuracy: 0.9959
# Training with L2=0.0001 and Dropout=0.3
# Epoch 1/25
# 111/111 [==============================] - 7s 20ms/step - loss: 1.0019 - categorical_accuracy: 0.7431 - val_loss: 6.1692 - val_categorical_accuracy: 0.0081
# Epoch 2/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.3148 - categorical_accuracy: 0.9518 - val_loss: 10.2569 - val_categorical_accuracy: 0.0392
# Epoch 3/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.2374 - categorical_accuracy: 0.9781 - val_loss: 4.5654 - val_categorical_accuracy: 0.3297
# Epoch 4/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.2032 - categorical_accuracy: 0.9897 - val_loss: 0.3708 - val_categorical_accuracy: 0.9270
# Epoch 5/25
# 111/111 [==============================] - 2s 19ms/step - loss: 0.1982 - categorical_accuracy: 0.9895 - val_loss: 0.1954 - val_categorical_accuracy: 0.9973
# Epoch 6/25
# 111/111 [==============================] - 2s 21ms/step - loss: 0.1885 - categorical_accuracy: 0.9935 - val_loss: 0.2014 - val_categorical_accuracy: 0.9919
# Epoch 7/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.1825 - categorical_accuracy: 0.9941 - val_loss: 0.1844 - val_categorical_accuracy: 0.9986
# Epoch 8/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.1744 - categorical_accuracy: 0.9958 - val_loss: 0.1893 - val_categorical_accuracy: 0.9986
# Epoch 9/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.1759 - categorical_accuracy: 0.9953 - val_loss: 0.1923 - val_categorical_accuracy: 0.9932
# Epoch 10/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.1691 - categorical_accuracy: 0.9967 - val_loss: 0.1874 - val_categorical_accuracy: 0.9973
# Epoch 11/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.1685 - categorical_accuracy: 0.9955 - val_loss: 0.1906 - val_categorical_accuracy: 0.9946
# Epoch 12/25
# 111/111 [==============================] - 2s 20ms/step - loss: 0.1658 - categorical_accuracy: 0.9960 - val_loss: 0.1874 - val_categorical_accuracy: 0.9959
# Epoch 13/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.1561 - categorical_accuracy: 0.9983 - val_loss: 0.1906 - val_categorical_accuracy: 0.9932
# Epoch 14/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.1494 - categorical_accuracy: 0.9990 - val_loss: 0.1830 - val_categorical_accuracy: 0.9932
# Epoch 15/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.1535 - categorical_accuracy: 0.9966 - val_loss: 0.1829 - val_categorical_accuracy: 0.9959
# Epoch 16/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.1497 - categorical_accuracy: 0.9969 - val_loss: 0.1854 - val_categorical_accuracy: 0.9932
# Epoch 17/25
# 111/111 [==============================] - 2s 19ms/step - loss: 0.1585 - categorical_accuracy: 0.9939 - val_loss: 0.2091 - val_categorical_accuracy: 0.9797
# Epoch 18/25
# 111/111 [==============================] - 2s 21ms/step - loss: 0.1547 - categorical_accuracy: 0.9953 - val_loss: 0.1729 - val_categorical_accuracy: 0.9946
# Epoch 19/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.1429 - categorical_accuracy: 0.9977 - val_loss: 0.1577 - val_categorical_accuracy: 0.9986
# Epoch 20/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.1417 - categorical_accuracy: 0.9969 - val_loss: 0.1517 - val_categorical_accuracy: 0.9973
# Epoch 21/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.1388 - categorical_accuracy: 0.9967 - val_loss: 0.1588 - val_categorical_accuracy: 0.9973
# Epoch 22/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.1378 - categorical_accuracy: 0.9972 - val_loss: 0.1523 - val_categorical_accuracy: 0.9986
# Epoch 23/25
# 111/111 [==============================] - 2s 19ms/step - loss: 0.1300 - categorical_accuracy: 0.9984 - val_loss: 0.1455 - val_categorical_accuracy: 0.9973
# Epoch 24/25
# 111/111 [==============================] - 2s 20ms/step - loss: 0.1255 - categorical_accuracy: 0.9983 - val_loss: 0.1342 - val_categorical_accuracy: 0.9986
# Epoch 25/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.1259 - categorical_accuracy: 0.9976 - val_loss: 0.1332 - val_categorical_accuracy: 0.9973
# Training with L2=0.0001 and Dropout=0.4
# Epoch 1/25
# 111/111 [==============================] - 6s 20ms/step - loss: 1.3845 - categorical_accuracy: 0.6434 - val_loss: 2.1825 - val_categorical_accuracy: 0.0635
# Epoch 2/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.3929 - categorical_accuracy: 0.9232 - val_loss: 3.4120 - val_categorical_accuracy: 0.3432
# Epoch 3/25
# 111/111 [==============================] - 2s 21ms/step - loss: 0.2638 - categorical_accuracy: 0.9672 - val_loss: 1.8447 - val_categorical_accuracy: 0.4662
# Epoch 4/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.2259 - categorical_accuracy: 0.9815 - val_loss: 1.6744 - val_categorical_accuracy: 0.5730
# Epoch 5/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.2235 - categorical_accuracy: 0.9832 - val_loss: 0.2271 - val_categorical_accuracy: 0.9865
# Epoch 6/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.2016 - categorical_accuracy: 0.9898 - val_loss: 0.1915 - val_categorical_accuracy: 0.9973
# Epoch 7/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.1927 - categorical_accuracy: 0.9919 - val_loss: 0.1959 - val_categorical_accuracy: 0.9973
# Epoch 8/25
# 111/111 [==============================] - 2s 19ms/step - loss: 0.1919 - categorical_accuracy: 0.9914 - val_loss: 0.1987 - val_categorical_accuracy: 0.9973
# Epoch 9/25
# 111/111 [==============================] - 2s 20ms/step - loss: 0.1834 - categorical_accuracy: 0.9938 - val_loss: 0.2004 - val_categorical_accuracy: 0.9973
# Epoch 10/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.1780 - categorical_accuracy: 0.9941 - val_loss: 0.1785 - val_categorical_accuracy: 0.9986
# Epoch 11/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.1813 - categorical_accuracy: 0.9925 - val_loss: 0.1791 - val_categorical_accuracy: 0.9973
# Epoch 12/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.1762 - categorical_accuracy: 0.9946 - val_loss: 0.2074 - val_categorical_accuracy: 0.9946
# Epoch 13/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.1725 - categorical_accuracy: 0.9952 - val_loss: 0.1884 - val_categorical_accuracy: 0.9959
# Epoch 14/25
# 111/111 [==============================] - 2s 20ms/step - loss: 0.1672 - categorical_accuracy: 0.9959 - val_loss: 0.1813 - val_categorical_accuracy: 0.9973
# Epoch 15/25
# 111/111 [==============================] - 2s 20ms/step - loss: 0.1708 - categorical_accuracy: 0.9936 - val_loss: 0.1807 - val_categorical_accuracy: 0.9973
# Epoch 16/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.1628 - categorical_accuracy: 0.9958 - val_loss: 0.1867 - val_categorical_accuracy: 0.9946
# Epoch 17/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.1665 - categorical_accuracy: 0.9942 - val_loss: 0.2052 - val_categorical_accuracy: 0.9851
# Epoch 18/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.1618 - categorical_accuracy: 0.9956 - val_loss: 0.1770 - val_categorical_accuracy: 0.9959
# Epoch 19/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.1545 - categorical_accuracy: 0.9970 - val_loss: 0.1710 - val_categorical_accuracy: 0.9959
# Epoch 20/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.1570 - categorical_accuracy: 0.9952 - val_loss: 0.1762 - val_categorical_accuracy: 0.9946
# Epoch 21/25
# 111/111 [==============================] - 2s 21ms/step - loss: 0.1507 - categorical_accuracy: 0.9970 - val_loss: 0.1675 - val_categorical_accuracy: 0.9959
# Epoch 22/25
# 111/111 [==============================] - 2s 19ms/step - loss: 0.1516 - categorical_accuracy: 0.9959 - val_loss: 0.1698 - val_categorical_accuracy: 0.9946
# Epoch 23/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.1477 - categorical_accuracy: 0.9967 - val_loss: 0.1624 - val_categorical_accuracy: 0.9946
# Epoch 24/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.1496 - categorical_accuracy: 0.9950 - val_loss: 0.1613 - val_categorical_accuracy: 0.9959
# Epoch 25/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.1484 - categorical_accuracy: 0.9963 - val_loss: 0.1598 - val_categorical_accuracy: 0.9959
# Training with L2=0.001 and Dropout=0.2
# Epoch 1/25
# 111/111 [==============================] - 7s 21ms/step - loss: 2.2115 - categorical_accuracy: 0.8079 - val_loss: 3.7073 - val_categorical_accuracy: 0.4000
# Epoch 2/25
# 111/111 [==============================] - 2s 17ms/step - loss: 1.5716 - categorical_accuracy: 0.9714 - val_loss: 5.5235 - val_categorical_accuracy: 0.3392
# Epoch 3/25
# 111/111 [==============================] - 2s 18ms/step - loss: 1.3824 - categorical_accuracy: 0.9819 - val_loss: 4.0872 - val_categorical_accuracy: 0.3811
# Epoch 4/25
# 111/111 [==============================] - 2s 17ms/step - loss: 1.1938 - categorical_accuracy: 0.9909 - val_loss: 2.0262 - val_categorical_accuracy: 0.6527
# Epoch 5/25
# 111/111 [==============================] - 2s 19ms/step - loss: 1.0259 - categorical_accuracy: 0.9953 - val_loss: 0.9941 - val_categorical_accuracy: 0.9770
# Epoch 6/25
# 111/111 [==============================] - 2s 21ms/step - loss: 0.8889 - categorical_accuracy: 0.9932 - val_loss: 0.8331 - val_categorical_accuracy: 0.9919
# Epoch 7/25
# 111/111 [==============================] - 2s 19ms/step - loss: 0.7862 - categorical_accuracy: 0.9931 - val_loss: 0.7443 - val_categorical_accuracy: 0.9932
# Epoch 8/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.6852 - categorical_accuracy: 0.9925 - val_loss: 0.6592 - val_categorical_accuracy: 0.9892
# Epoch 9/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.6181 - categorical_accuracy: 0.9912 - val_loss: 0.5827 - val_categorical_accuracy: 0.9932
# Epoch 10/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.5275 - categorical_accuracy: 0.9958 - val_loss: 0.4976 - val_categorical_accuracy: 0.9919
# Epoch 11/25
# 111/111 [==============================] - 2s 20ms/step - loss: 0.4580 - categorical_accuracy: 0.9950 - val_loss: 0.4514 - val_categorical_accuracy: 0.9919
# Epoch 12/25
# 111/111 [==============================] - 2s 20ms/step - loss: 0.4071 - categorical_accuracy: 0.9963 - val_loss: 0.3894 - val_categorical_accuracy: 0.9946
# Epoch 13/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.3732 - categorical_accuracy: 0.9925 - val_loss: 0.4245 - val_categorical_accuracy: 0.9865
# Epoch 14/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.3691 - categorical_accuracy: 0.9948 - val_loss: 0.3617 - val_categorical_accuracy: 0.9932
# Epoch 15/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.3201 - categorical_accuracy: 0.9967 - val_loss: 0.3073 - val_categorical_accuracy: 0.9932
# Epoch 16/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.3104 - categorical_accuracy: 0.9924 - val_loss: 0.3476 - val_categorical_accuracy: 0.9959
# Epoch 17/25
# 111/111 [==============================] - 2s 19ms/step - loss: 0.3214 - categorical_accuracy: 0.9897 - val_loss: 0.3452 - val_categorical_accuracy: 0.9905
# Epoch 18/25
# 111/111 [==============================] - 2s 21ms/step - loss: 0.2721 - categorical_accuracy: 0.9980 - val_loss: 0.2557 - val_categorical_accuracy: 0.9973
# Epoch 19/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.2311 - categorical_accuracy: 0.9963 - val_loss: 0.2457 - val_categorical_accuracy: 0.9919
# Epoch 20/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.2644 - categorical_accuracy: 0.9895 - val_loss: 0.3717 - val_categorical_accuracy: 0.9757
# Epoch 21/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.2768 - categorical_accuracy: 0.9908 - val_loss: 0.3128 - val_categorical_accuracy: 0.9865
# Epoch 22/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.2497 - categorical_accuracy: 0.9934 - val_loss: 0.2659 - val_categorical_accuracy: 0.9919
# Epoch 23/25
# 111/111 [==============================] - 2s 19ms/step - loss: 0.2457 - categorical_accuracy: 0.9921 - val_loss: 0.3031 - val_categorical_accuracy: 0.9797
# Epoch 24/25
# 111/111 [==============================] - 2s 20ms/step - loss: 0.2333 - categorical_accuracy: 0.9936 - val_loss: 0.2437 - val_categorical_accuracy: 0.9905
# Epoch 25/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.2254 - categorical_accuracy: 0.9943 - val_loss: 0.4248 - val_categorical_accuracy: 0.9392
# Training with L2=0.001 and Dropout=0.3
# Epoch 1/25
# 111/111 [==============================] - 6s 20ms/step - loss: 2.4866 - categorical_accuracy: 0.7327 - val_loss: 7.2455 - val_categorical_accuracy: 0.0081
# Epoch 2/25
# 111/111 [==============================] - 2s 19ms/step - loss: 1.6730 - categorical_accuracy: 0.9574 - val_loss: 6.8731 - val_categorical_accuracy: 0.2068
# Epoch 3/25
# 111/111 [==============================] - 2s 21ms/step - loss: 1.4604 - categorical_accuracy: 0.9843 - val_loss: 7.6059 - val_categorical_accuracy: 0.2473
# Epoch 4/25
# 111/111 [==============================] - 2s 17ms/step - loss: 1.2966 - categorical_accuracy: 0.9895 - val_loss: 2.9966 - val_categorical_accuracy: 0.4527
# Epoch 5/25
# 111/111 [==============================] - 2s 18ms/step - loss: 1.1455 - categorical_accuracy: 0.9901 - val_loss: 1.1088 - val_categorical_accuracy: 0.9770
# Epoch 6/25
# 111/111 [==============================] - 2s 18ms/step - loss: 1.0168 - categorical_accuracy: 0.9918 - val_loss: 0.9609 - val_categorical_accuracy: 0.9919
# Epoch 7/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.8929 - categorical_accuracy: 0.9917 - val_loss: 0.8503 - val_categorical_accuracy: 0.9905
# Epoch 8/25
# 111/111 [==============================] - 2s 19ms/step - loss: 0.7833 - categorical_accuracy: 0.9945 - val_loss: 0.7395 - val_categorical_accuracy: 0.9932
# Epoch 9/25
# 111/111 [==============================] - 2s 21ms/step - loss: 0.6793 - categorical_accuracy: 0.9953 - val_loss: 0.6699 - val_categorical_accuracy: 0.9851
# Epoch 10/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.6092 - categorical_accuracy: 0.9942 - val_loss: 0.6136 - val_categorical_accuracy: 0.9919
# Epoch 11/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.5531 - categorical_accuracy: 0.9928 - val_loss: 0.5395 - val_categorical_accuracy: 0.9892
# Epoch 12/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.5272 - categorical_accuracy: 0.9884 - val_loss: 0.5227 - val_categorical_accuracy: 0.9905
# Epoch 13/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.4671 - categorical_accuracy: 0.9943 - val_loss: 0.4647 - val_categorical_accuracy: 0.9878
# Epoch 14/25
# 111/111 [==============================] - 2s 19ms/step - loss: 0.4374 - categorical_accuracy: 0.9912 - val_loss: 0.4271 - val_categorical_accuracy: 0.9959
# Epoch 15/25
# 111/111 [==============================] - 2s 21ms/step - loss: 0.3878 - categorical_accuracy: 0.9938 - val_loss: 0.3876 - val_categorical_accuracy: 0.9905
# Epoch 16/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.3445 - categorical_accuracy: 0.9963 - val_loss: 0.3531 - val_categorical_accuracy: 0.9946
# Epoch 17/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.3354 - categorical_accuracy: 0.9909 - val_loss: 0.3692 - val_categorical_accuracy: 0.9905
# Epoch 18/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.3209 - categorical_accuracy: 0.9945 - val_loss: 0.3456 - val_categorical_accuracy: 0.9865
# Epoch 19/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.2990 - categorical_accuracy: 0.9938 - val_loss: 0.2946 - val_categorical_accuracy: 0.9959
# Epoch 20/25
# 111/111 [==============================] - 2s 21ms/step - loss: 0.2730 - categorical_accuracy: 0.9949 - val_loss: 0.2720 - val_categorical_accuracy: 0.9919
# Epoch 21/25
# 111/111 [==============================] - 3s 23ms/step - loss: 0.2512 - categorical_accuracy: 0.9949 - val_loss: 0.3441 - val_categorical_accuracy: 0.9689
# Epoch 22/25
# 111/111 [==============================] - 2s 21ms/step - loss: 0.3073 - categorical_accuracy: 0.9873 - val_loss: 0.3193 - val_categorical_accuracy: 0.9838
# Epoch 23/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.2720 - categorical_accuracy: 0.9955 - val_loss: 0.2596 - val_categorical_accuracy: 0.9946
# Epoch 24/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.2143 - categorical_accuracy: 0.9982 - val_loss: 0.2352 - val_categorical_accuracy: 0.9878
# Epoch 25/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.2484 - categorical_accuracy: 0.9860 - val_loss: 0.3378 - val_categorical_accuracy: 0.9932
# Training with L2=0.001 and Dropout=0.4
# Epoch 1/25
# 111/111 [==============================] - 8s 22ms/step - loss: 2.8630 - categorical_accuracy: 0.6460 - val_loss: 7.9505 - val_categorical_accuracy: 0.0081
# Epoch 2/25
# 111/111 [==============================] - 2s 18ms/step - loss: 1.8696 - categorical_accuracy: 0.9083 - val_loss: 9.1181 - val_categorical_accuracy: 0.0189
# Epoch 3/25
# 111/111 [==============================] - 2s 17ms/step - loss: 1.6070 - categorical_accuracy: 0.9605 - val_loss: 5.2568 - val_categorical_accuracy: 0.3216
# Epoch 4/25
# 111/111 [==============================] - 2s 18ms/step - loss: 1.4424 - categorical_accuracy: 0.9772 - val_loss: 3.0461 - val_categorical_accuracy: 0.4932
# Epoch 5/25
# 111/111 [==============================] - 2s 17ms/step - loss: 1.3038 - categorical_accuracy: 0.9825 - val_loss: 1.4472 - val_categorical_accuracy: 0.8973
# Epoch 6/25
# 111/111 [==============================] - 2s 21ms/step - loss: 1.1702 - categorical_accuracy: 0.9867 - val_loss: 1.1189 - val_categorical_accuracy: 0.9865
# Epoch 7/25
# 111/111 [==============================] - 2s 17ms/step - loss: 1.0429 - categorical_accuracy: 0.9926 - val_loss: 0.9803 - val_categorical_accuracy: 0.9973
# Epoch 8/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.9358 - categorical_accuracy: 0.9925 - val_loss: 0.8956 - val_categorical_accuracy: 0.9892
# Epoch 9/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.8518 - categorical_accuracy: 0.9898 - val_loss: 0.8123 - val_categorical_accuracy: 0.9919
# Epoch 10/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.7642 - categorical_accuracy: 0.9926 - val_loss: 0.7441 - val_categorical_accuracy: 0.9851
# Epoch 11/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.6842 - categorical_accuracy: 0.9926 - val_loss: 0.6617 - val_categorical_accuracy: 0.9905
# Epoch 12/25
# 111/111 [==============================] - 2s 20ms/step - loss: 0.6361 - categorical_accuracy: 0.9909 - val_loss: 0.6293 - val_categorical_accuracy: 0.9919
# Epoch 13/25
# 111/111 [==============================] - 2s 19ms/step - loss: 0.5907 - categorical_accuracy: 0.9909 - val_loss: 0.6232 - val_categorical_accuracy: 0.9865
# Epoch 14/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.5323 - categorical_accuracy: 0.9929 - val_loss: 0.5086 - val_categorical_accuracy: 0.9959
# Epoch 15/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.4848 - categorical_accuracy: 0.9938 - val_loss: 0.4603 - val_categorical_accuracy: 0.9973
# Epoch 16/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.4394 - categorical_accuracy: 0.9936 - val_loss: 0.4480 - val_categorical_accuracy: 0.9892
# Epoch 17/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.4034 - categorical_accuracy: 0.9956 - val_loss: 0.4212 - val_categorical_accuracy: 0.9892
# Epoch 18/25
# 111/111 [==============================] - 2s 20ms/step - loss: 0.3600 - categorical_accuracy: 0.9958 - val_loss: 0.4843 - val_categorical_accuracy: 0.9554
# Epoch 19/25
# 111/111 [==============================] - 2s 19ms/step - loss: 0.3911 - categorical_accuracy: 0.9877 - val_loss: 0.4043 - val_categorical_accuracy: 0.9892
# Epoch 20/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.3973 - categorical_accuracy: 0.9884 - val_loss: 0.3889 - val_categorical_accuracy: 0.9946
# Epoch 21/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.3775 - categorical_accuracy: 0.9919 - val_loss: 0.3599 - val_categorical_accuracy: 0.9932
# Epoch 22/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.3310 - categorical_accuracy: 0.9946 - val_loss: 0.3146 - val_categorical_accuracy: 0.9946
# Epoch 23/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.3117 - categorical_accuracy: 0.9934 - val_loss: 0.3280 - val_categorical_accuracy: 0.9905
# Epoch 24/25
# 111/111 [==============================] - 2s 21ms/step - loss: 0.3279 - categorical_accuracy: 0.9891 - val_loss: 0.3401 - val_categorical_accuracy: 0.9932
# Epoch 25/25
# 111/111 [==============================] - 2s 20ms/step - loss: 0.3236 - categorical_accuracy: 0.9908 - val_loss: 0.3395 - val_categorical_accuracy: 0.9919
# Training with L2=0.01 and Dropout=0.2
# Epoch 1/25
# 111/111 [==============================] - 6s 20ms/step - loss: 13.2817 - categorical_accuracy: 0.8042 - val_loss: 10.6528 - val_categorical_accuracy: 0.2757
# Epoch 2/25
# 111/111 [==============================] - 2s 17ms/step - loss: 6.7517 - categorical_accuracy: 0.9682 - val_loss: 6.3962 - val_categorical_accuracy: 0.3351
# Epoch 3/25
# 111/111 [==============================] - 2s 19ms/step - loss: 3.4476 - categorical_accuracy: 0.9789 - val_loss: 5.4544 - val_categorical_accuracy: 0.2784
# Epoch 4/25
# 111/111 [==============================] - 2s 21ms/step - loss: 1.9583 - categorical_accuracy: 0.9818 - val_loss: 5.1175 - val_categorical_accuracy: 0.3446
# Epoch 5/25
# 111/111 [==============================] - 2s 18ms/step - loss: 1.2955 - categorical_accuracy: 0.9786 - val_loss: 1.7214 - val_categorical_accuracy: 0.7757
# Epoch 6/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.9879 - categorical_accuracy: 0.9798 - val_loss: 1.0817 - val_categorical_accuracy: 0.9068
# Epoch 7/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.7236 - categorical_accuracy: 0.9846 - val_loss: 0.7140 - val_categorical_accuracy: 0.9649
# Epoch 8/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.6123 - categorical_accuracy: 0.9799 - val_loss: 0.6369 - val_categorical_accuracy: 0.9824
# Epoch 9/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.5670 - categorical_accuracy: 0.9813 - val_loss: 0.5827 - val_categorical_accuracy: 0.9797
# Epoch 10/25
# 111/111 [==============================] - 2s 20ms/step - loss: 0.5770 - categorical_accuracy: 0.9801 - val_loss: 0.7951 - val_categorical_accuracy: 0.9041
# Epoch 11/25
# 111/111 [==============================] - 2s 19ms/step - loss: 0.5428 - categorical_accuracy: 0.9809 - val_loss: 0.6004 - val_categorical_accuracy: 0.9527
# Epoch 12/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.5497 - categorical_accuracy: 0.9775 - val_loss: 0.4711 - val_categorical_accuracy: 0.9919
# Epoch 13/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.4793 - categorical_accuracy: 0.9798 - val_loss: 1.6657 - val_categorical_accuracy: 0.7946
# Epoch 14/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.4827 - categorical_accuracy: 0.9813 - val_loss: 0.5741 - val_categorical_accuracy: 0.9365
# Epoch 15/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.4272 - categorical_accuracy: 0.9836 - val_loss: 0.5427 - val_categorical_accuracy: 0.9581
# Epoch 16/25
# 111/111 [==============================] - 2s 20ms/step - loss: 0.5008 - categorical_accuracy: 0.9795 - val_loss: 0.4454 - val_categorical_accuracy: 0.9838
# Epoch 17/25
# 111/111 [==============================] - 2s 20ms/step - loss: 0.4196 - categorical_accuracy: 0.9839 - val_loss: 0.5497 - val_categorical_accuracy: 0.9095
# Epoch 18/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.4093 - categorical_accuracy: 0.9832 - val_loss: 0.4063 - val_categorical_accuracy: 0.9811
# Epoch 19/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.4356 - categorical_accuracy: 0.9815 - val_loss: 1.9385 - val_categorical_accuracy: 0.6784
# Epoch 20/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.3795 - categorical_accuracy: 0.9868 - val_loss: 0.4080 - val_categorical_accuracy: 0.9865
# Epoch 21/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.4542 - categorical_accuracy: 0.9813 - val_loss: 0.9780 - val_categorical_accuracy: 0.8189
# Epoch 22/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.4255 - categorical_accuracy: 0.9827 - val_loss: 0.4582 - val_categorical_accuracy: 0.9878
# Epoch 23/25
# 111/111 [==============================] - 2s 21ms/step - loss: 0.4079 - categorical_accuracy: 0.9840 - val_loss: 1.5929 - val_categorical_accuracy: 0.7216
# Epoch 24/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.4103 - categorical_accuracy: 0.9846 - val_loss: 0.4639 - val_categorical_accuracy: 0.9608
# Epoch 25/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.3662 - categorical_accuracy: 0.9850 - val_loss: 0.3462 - val_categorical_accuracy: 0.9838
# Training with L2=0.01 and Dropout=0.3
# Epoch 1/25
# 111/111 [==============================] - 6s 20ms/step - loss: 13.9430 - categorical_accuracy: 0.7290 - val_loss: 12.9267 - val_categorical_accuracy: 0.2473
# Epoch 2/25
# 111/111 [==============================] - 2s 20ms/step - loss: 7.6634 - categorical_accuracy: 0.9474 - val_loss: 7.0342 - val_categorical_accuracy: 0.3405
# Epoch 3/25
# 111/111 [==============================] - 2s 21ms/step - loss: 4.1853 - categorical_accuracy: 0.9767 - val_loss: 6.5900 - val_categorical_accuracy: 0.2811
# Epoch 4/25
# 111/111 [==============================] - 2s 18ms/step - loss: 2.4490 - categorical_accuracy: 0.9795 - val_loss: 4.3931 - val_categorical_accuracy: 0.4324
# Epoch 5/25
# 111/111 [==============================] - 2s 18ms/step - loss: 1.5810 - categorical_accuracy: 0.9786 - val_loss: 2.8100 - val_categorical_accuracy: 0.5230
# Epoch 6/25
# 111/111 [==============================] - 2s 17ms/step - loss: 1.1562 - categorical_accuracy: 0.9793 - val_loss: 1.0575 - val_categorical_accuracy: 0.9595
# Epoch 7/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.8931 - categorical_accuracy: 0.9795 - val_loss: 0.9106 - val_categorical_accuracy: 0.9757
# Epoch 8/25
# 111/111 [==============================] - 2s 19ms/step - loss: 0.7821 - categorical_accuracy: 0.9829 - val_loss: 0.9544 - val_categorical_accuracy: 0.9297
# Epoch 9/25
# 111/111 [==============================] - 2s 21ms/step - loss: 0.6964 - categorical_accuracy: 0.9809 - val_loss: 0.7252 - val_categorical_accuracy: 0.9703
# Epoch 10/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.6411 - categorical_accuracy: 0.9812 - val_loss: 0.7622 - val_categorical_accuracy: 0.9527
# Epoch 11/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.6031 - categorical_accuracy: 0.9826 - val_loss: 0.5353 - val_categorical_accuracy: 0.9730
# Epoch 12/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.5756 - categorical_accuracy: 0.9765 - val_loss: 0.7851 - val_categorical_accuracy: 0.9419
# Epoch 13/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.6238 - categorical_accuracy: 0.9789 - val_loss: 0.9632 - val_categorical_accuracy: 0.8730
# Epoch 14/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.5374 - categorical_accuracy: 0.9819 - val_loss: 0.7859 - val_categorical_accuracy: 0.9230
# Epoch 15/25
# 111/111 [==============================] - 2s 22ms/step - loss: 0.5851 - categorical_accuracy: 0.9772 - val_loss: 0.5648 - val_categorical_accuracy: 0.9919
# Epoch 16/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.5224 - categorical_accuracy: 0.9802 - val_loss: 0.5399 - val_categorical_accuracy: 0.9919
# Epoch 17/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.4973 - categorical_accuracy: 0.9802 - val_loss: 0.8839 - val_categorical_accuracy: 0.8919
# Epoch 18/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.5078 - categorical_accuracy: 0.9786 - val_loss: 0.5492 - val_categorical_accuracy: 0.9676
# Epoch 19/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.4734 - categorical_accuracy: 0.9813 - val_loss: 0.6705 - val_categorical_accuracy: 0.9338
# Epoch 20/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.4136 - categorical_accuracy: 0.9878 - val_loss: 0.3507 - val_categorical_accuracy: 0.9892
# Epoch 21/25
# 111/111 [==============================] - 2s 21ms/step - loss: 0.4734 - categorical_accuracy: 0.9793 - val_loss: 0.7195 - val_categorical_accuracy: 0.9324
# Epoch 22/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.5081 - categorical_accuracy: 0.9801 - val_loss: 0.4890 - val_categorical_accuracy: 0.9973
# Epoch 23/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.4493 - categorical_accuracy: 0.9861 - val_loss: 0.4438 - val_categorical_accuracy: 0.9784
# Epoch 24/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.4558 - categorical_accuracy: 0.9808 - val_loss: 0.4340 - val_categorical_accuracy: 0.9865
# Epoch 25/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.4354 - categorical_accuracy: 0.9851 - val_loss: 0.4593 - val_categorical_accuracy: 0.9676
# Training with L2=0.01 and Dropout=0.4
# Epoch 1/25
# 111/111 [==============================] - 7s 20ms/step - loss: 14.6363 - categorical_accuracy: 0.6714 - val_loss: 13.3591 - val_categorical_accuracy: 0.3500
# Epoch 2/25
# 111/111 [==============================] - 2s 17ms/step - loss: 8.8334 - categorical_accuracy: 0.9338 - val_loss: 10.8916 - val_categorical_accuracy: 0.2757
# Epoch 3/25
# 111/111 [==============================] - 2s 17ms/step - loss: 5.2198 - categorical_accuracy: 0.9676 - val_loss: 7.8246 - val_categorical_accuracy: 0.2838
# Epoch 4/25
# 111/111 [==============================] - 2s 17ms/step - loss: 3.2543 - categorical_accuracy: 0.9737 - val_loss: 4.2369 - val_categorical_accuracy: 0.5095
# Epoch 5/25
# 111/111 [==============================] - 2s 20ms/step - loss: 2.1175 - categorical_accuracy: 0.9777 - val_loss: 2.1680 - val_categorical_accuracy: 0.7973
# Epoch 6/25
# 111/111 [==============================] - 2s 21ms/step - loss: 1.4799 - categorical_accuracy: 0.9805 - val_loss: 1.3434 - val_categorical_accuracy: 0.9473
# Epoch 7/25
# 111/111 [==============================] - 2s 17ms/step - loss: 1.1477 - categorical_accuracy: 0.9768 - val_loss: 1.1353 - val_categorical_accuracy: 0.9500
# Epoch 8/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.9944 - categorical_accuracy: 0.9768 - val_loss: 1.0185 - val_categorical_accuracy: 0.9527
# Epoch 9/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.8404 - categorical_accuracy: 0.9809 - val_loss: 0.8573 - val_categorical_accuracy: 0.9662
# Epoch 10/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.7461 - categorical_accuracy: 0.9796 - val_loss: 0.7159 - val_categorical_accuracy: 0.9851
# Epoch 11/25
# 111/111 [==============================] - 2s 19ms/step - loss: 0.7360 - categorical_accuracy: 0.9786 - val_loss: 0.7540 - val_categorical_accuracy: 0.9770
# Epoch 12/25
# 111/111 [==============================] - 2s 21ms/step - loss: 0.7315 - categorical_accuracy: 0.9764 - val_loss: 0.6682 - val_categorical_accuracy: 0.9757
# Epoch 13/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.6518 - categorical_accuracy: 0.9805 - val_loss: 0.7881 - val_categorical_accuracy: 0.9243
# Epoch 14/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.7479 - categorical_accuracy: 0.9719 - val_loss: 1.0893 - val_categorical_accuracy: 0.8851
# Epoch 15/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.5977 - categorical_accuracy: 0.9816 - val_loss: 0.6949 - val_categorical_accuracy: 0.9514
# Epoch 16/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.6704 - categorical_accuracy: 0.9786 - val_loss: 0.6382 - val_categorical_accuracy: 0.9676
# Epoch 17/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.6427 - categorical_accuracy: 0.9765 - val_loss: 0.7825 - val_categorical_accuracy: 0.9216
# Epoch 18/25
# 111/111 [==============================] - 2s 21ms/step - loss: 0.6097 - categorical_accuracy: 0.9796 - val_loss: 0.6229 - val_categorical_accuracy: 0.9892
# Epoch 19/25
# 111/111 [==============================] - 2s 20ms/step - loss: 0.7078 - categorical_accuracy: 0.9748 - val_loss: 0.6687 - val_categorical_accuracy: 0.9878
# Epoch 20/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.6290 - categorical_accuracy: 0.9772 - val_loss: 0.6527 - val_categorical_accuracy: 0.9811
# Epoch 21/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.6344 - categorical_accuracy: 0.9750 - val_loss: 3.3359 - val_categorical_accuracy: 0.5243
# Epoch 22/25
# 111/111 [==============================] - 2s 17ms/step - loss: 0.6302 - categorical_accuracy: 0.9820 - val_loss: 0.5431 - val_categorical_accuracy: 0.9878
# Epoch 23/25
# 111/111 [==============================] - 2s 18ms/step - loss: 0.5602 - categorical_accuracy: 0.9802 - val_loss: 0.6199 - val_categorical_accuracy: 0.9730
# Epoch 24/25
# 111/111 [==============================] - 2s 21ms/step - loss: 0.6539 - categorical_accuracy: 0.9761 - val_loss: 0.6046 - val_categorical_accuracy: 0.9865
# Epoch 25/25
# 111/111 [==============================] - 2s 20ms/step - loss: 0.5427 - categorical_accuracy: 0.9823 - val_loss: 0.6679 - val_categorical_accuracy: 0.9662
# L2=0.0001, Dropout=0.2 - Validation Accuracy: 0.995945930480957, Validation Loss: 0.13864101469516754
# L2=0.0001, Dropout=0.3 - Validation Accuracy: 0.9972972869873047, Validation Loss: 0.1332099884748459
# L2=0.0001, Dropout=0.4 - Validation Accuracy: 0.995945930480957, Validation Loss: 0.15975134074687958
# L2=0.001, Dropout=0.2 - Validation Accuracy: 0.9391891956329346, Validation Loss: 0.4248437285423279
# L2=0.001, Dropout=0.3 - Validation Accuracy: 0.9932432174682617, Validation Loss: 0.3378019332885742
# L2=0.001, Dropout=0.4 - Validation Accuracy: 0.9918919205665588, Validation Loss: 0.33951425552368164
# L2=0.01, Dropout=0.2 - Validation Accuracy: 0.9837837815284729, Validation Loss: 0.346191942691803
# L2=0.01, Dropout=0.3 - Validation Accuracy: 0.9675675630569458, Validation Loss: 0.45929887890815735
# L2=0.01, Dropout=0.4 - Validation Accuracy: 0.9662162065505981, Validation Loss: 0.6678511500358582

# %% [markdown]
# * The combination of L2=0.0001 and Dropout=0.4 provides the best balance of regularization and dropout due to its **Highest Validation Accuracy and Low Validation Loss**, leading to excellent generalization performance on the validation set. This combination effectively mitigates overfitting while maintaining high accuracy, making it the optimal choice among the tested configurations.
# We can see that this combination gives the best

# %%
import tensorflow as tf

# Improved VGG-like CNN model for shape classification with added regularization
model_VGG_1_improved = tf.keras.Sequential([
    # VGG block 1
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=INPUT_DIM, kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.4),

    # VGG block 2
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),

    # VGG block 3
    tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.6),
    tf.keras.layers.Dense(OUTPUT_CLASSES_SHAPE, activation='softmax'),
])

# %%
model_VGG_1_improved.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['categorical_accuracy'])

# %%
model_VGG_1_improved.summary()
# Out:
# Model: "sequential_46"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_228 (Conv2D)         (None, 28, 28, 64)        640
#
#  conv2d_229 (Conv2D)         (None, 28, 28, 64)        36928
#
#  max_pooling2d_114 (MaxPool  (None, 14, 14, 64)        0
#  ing2D)
#
#  batch_normalization_140 (B  (None, 14, 14, 64)        256
#  atchNormalization)
#
#  dropout_140 (Dropout)       (None, 14, 14, 64)        0
#
#  conv2d_230 (Conv2D)         (None, 14, 14, 128)       73856
#
#  conv2d_231 (Conv2D)         (None, 14, 14, 128)       147584
#
#  max_pooling2d_115 (MaxPool  (None, 7, 7, 128)         0
#  ing2D)
#
#  batch_normalization_141 (B  (None, 7, 7, 128)         512
#  atchNormalization)
#
#  dropout_141 (Dropout)       (None, 7, 7, 128)         0
#
#  conv2d_232 (Conv2D)         (None, 7, 7, 256)         295168
#
#  conv2d_233 (Conv2D)         (None, 7, 7, 256)         590080
#
#  max_pooling2d_116 (MaxPool  (None, 3, 3, 256)         0
#  ing2D)
#
#  batch_normalization_142 (B  (None, 3, 3, 256)         1024
#  atchNormalization)
#
#  dropout_142 (Dropout)       (None, 3, 3, 256)         0
#
#  flatten_42 (Flatten)        (None, 2304)              0
#
#  dense_76 (Dense)            (None, 512)               1180160
#
#  batch_normalization_143 (B  (None, 512)               2048
#  atchNormalization)
#
#  dropout_143 (Dropout)       (None, 512)               0
#
#  dense_77 (Dense)            (None, 5)                 2565
#
# =================================================================
# Total params: 2330821 (8.89 MB)
# Trainable params: 2328901 (8.88 MB)
# Non-trainable params: 1920 (7.50 KB)
# _________________________________________________________________

# %%
# Generating the image for model architecture
visualkeras.layered_view(model_VGG_1_improved, scale_xy=2, scale_z=1, max_z=50, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=1193x111>

# %%
tf.keras.utils.plot_model(model_VGG_1_improved, show_shapes=True)

# %% [markdown]
# Fit the model

# %%
history_VGG_1_improved = model_VGG_1_improved.fit(
    train_generator_shape,
    validation_data=validation_generator_shape,
    epochs=50,
    verbose=0
)

# %%
plot_learning_curve(history_VGG_1_improved.history['loss'], history_VGG_1_improved.history['val_loss'],
                    history_VGG_1_improved.history['categorical_accuracy'], history_VGG_1_improved.history['val_categorical_accuracy'],
                    metric_name='Accuracy')

# %%
model_VGG_1_improved.evaluate(test_generator_shape)
# Out:
# 35/35 [==============================] - 0s 5ms/step - loss: 0.2787 - categorical_accuracy: 0.9888
# [0.27870646119117737, 0.9888092875480652]

# %% [markdown]
# ### Model 2.2 Type classification using VGG CNN

# %%
model_VGG_2 = tf.keras.Sequential([
    # VGG block 1
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=INPUT_DIM),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D((2, 2)),

    # VGG block 2
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D((2, 2)),

    # VGG block 3
    tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D((2, 2)),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(OUTPUT_CLASSES_TYPE, activation='softmax'),
])

# %%
model_VGG_2.summary()
# Out:
# Model: "sequential_47"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_234 (Conv2D)         (None, 28, 28, 64)        640
#
#  conv2d_235 (Conv2D)         (None, 28, 28, 64)        36928
#
#  max_pooling2d_117 (MaxPool  (None, 14, 14, 64)        0
#  ing2D)
#
#  conv2d_236 (Conv2D)         (None, 14, 14, 128)       73856
#
#  conv2d_237 (Conv2D)         (None, 14, 14, 128)       147584
#
#  max_pooling2d_118 (MaxPool  (None, 7, 7, 128)         0
#  ing2D)
#
#  conv2d_238 (Conv2D)         (None, 7, 7, 256)         295168
#
#  conv2d_239 (Conv2D)         (None, 7, 7, 256)         590080
#
#  max_pooling2d_119 (MaxPool  (None, 3, 3, 256)         0
#  ing2D)
#
#  flatten_43 (Flatten)        (None, 2304)              0
#
#  dense_78 (Dense)            (None, 512)               1180160
#
#  dense_79 (Dense)            (None, 16)                8208
#
# =================================================================
# Total params: 2332624 (8.90 MB)
# Trainable params: 2332624 (8.90 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Generating the image for model architecture
visualkeras.layered_view(model_VGG_2, scale_xy=2, scale_z=1, max_z=50, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=713x111>

# %%
tf.keras.utils.plot_model(model_VGG_2, show_shapes=True)

# %%
model_VGG_2.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['categorical_accuracy'])

# %%
history_VGG_2 = model_VGG_2.fit(
    train_generator_type,
    validation_data=validation_generator_type,
    epochs=50,
    verbose=0
)

# %%
plot_learning_curve(history_VGG_2.history['loss'], history_VGG_1.history['val_loss'],
                    history_VGG_2.history['categorical_accuracy'], history_VGG_1.history['val_categorical_accuracy'],
                    metric_name='Accuracy')

# %%
model_VGG_2.evaluate(test_generator_type)
# Out:
# 35/35 [==============================] - 0s 6ms/step - loss: 0.2496 - categorical_accuracy: 0.9794
# [0.24958105385303497, 0.9794091582298279]

# %% [markdown]
# ### Add Normalisation and Dropout layers

# %%
# Improved VGG-like CNN model for shape classification
model_VGG_2_improved = tf.keras.Sequential([
    # VGG block 1
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=INPUT_DIM),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.25),

    # VGG block 2
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.25),

    # VGG block 3
    tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.25),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(OUTPUT_CLASSES_TYPE, activation='softmax'),
])

# %%
model_VGG_2_improved.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['categorical_accuracy'])

# %%
model_VGG_2_improved.summary()
# Out:
# Model: "sequential_48"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_240 (Conv2D)         (None, 28, 28, 64)        640
#
#  conv2d_241 (Conv2D)         (None, 28, 28, 64)        36928
#
#  max_pooling2d_120 (MaxPool  (None, 14, 14, 64)        0
#  ing2D)
#
#  batch_normalization_144 (B  (None, 14, 14, 64)        256
#  atchNormalization)
#
#  dropout_144 (Dropout)       (None, 14, 14, 64)        0
#
#  conv2d_242 (Conv2D)         (None, 14, 14, 128)       73856
#
#  conv2d_243 (Conv2D)         (None, 14, 14, 128)       147584
#
#  max_pooling2d_121 (MaxPool  (None, 7, 7, 128)         0
#  ing2D)
#
#  batch_normalization_145 (B  (None, 7, 7, 128)         512
#  atchNormalization)
#
#  dropout_145 (Dropout)       (None, 7, 7, 128)         0
#
#  conv2d_244 (Conv2D)         (None, 7, 7, 256)         295168
#
#  conv2d_245 (Conv2D)         (None, 7, 7, 256)         590080
#
#  max_pooling2d_122 (MaxPool  (None, 3, 3, 256)         0
#  ing2D)
#
#  batch_normalization_146 (B  (None, 3, 3, 256)         1024
#  atchNormalization)
#
#  dropout_146 (Dropout)       (None, 3, 3, 256)         0
#
#  flatten_44 (Flatten)        (None, 2304)              0
#
#  dense_80 (Dense)            (None, 512)               1180160
#
#  batch_normalization_147 (B  (None, 512)               2048
#  atchNormalization)
#
#  dropout_147 (Dropout)       (None, 512)               0
#
#  dense_81 (Dense)            (None, 16)                8208
#
# =================================================================
# Total params: 2336464 (8.91 MB)
# Trainable params: 2334544 (8.91 MB)
# Non-trainable params: 1920 (7.50 KB)
# _________________________________________________________________

# %%
# Generating the image for model architecture
visualkeras.layered_view(model_VGG_2_improved, scale_xy=2, scale_z=1, max_z=50, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=1193x111>

# %%
tf.keras.utils.plot_model(model_VGG_2_improved, show_shapes=True)

# %% [markdown]
# Fit the model

# %%
history_VGG_2_improved = model_VGG_2_improved.fit(
    train_generator_type,
    validation_data=validation_generator_type,
    epochs=50,
    verbose=0
)

# %%
plot_learning_curve(history_VGG_1_improved.history['loss'], history_VGG_1_improved.history['val_loss'],
                    history_VGG_1_improved.history['categorical_accuracy'], history_VGG_1_improved.history['val_categorical_accuracy'],
                    metric_name='Accuracy')

# %%
model_VGG_2_improved.evaluate(test_generator_type)

# %% [markdown]
# ## 6. Testing the final model

# %% [markdown]
# Display prediction result

# %% [markdown]
# show green color when correct & red when incorrect Actual Vs Predicted

# %%
# # Data generator for test data
# test_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

# batch_size = 1

# test_generator = test_datagen.flow_from_dataframe(
#         dataframe=test_data,
#         directory='./',
#         x_col="image_path",
#         y_col=["Shape", "Type"],  # Assuming you want to predict both Shape and Type
#         target_size=(32, 32),
#         batch_size=batch_size,
#         class_mode='multi_output')  # Set to 'multi_output' to match your model's configuration

# %%
# # Data generator for test data
# test_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

# batch_size = 32  # or any batch size that fits your memory constraints

# test_generator = test_datagen.flow_from_dataframe(
#         dataframe=test_data,
#         directory='./',
#         x_col="image_path",
#         y_col=["Shape", "Type"],  # Assuming you want to predict both Shape and Type
#         target_size=(28, 28),  # Ensure target size matches the input size of the network
#         batch_size=batch_size,
#         class_mode='multi_output')  # Set to 'multi_output' to match your model's configuration

# # Evaluate the model
# final_model.evaluate(test_generator)

# %%
# ## still wrong

# import matplotlib.pyplot as plt
# import numpy as np

# # Increase the figure size and font size for better visibility
# plt.figure(figsize=(20, 5))  # Adjust the figure size as needed
# font = {'family' : 'serif',
#         'weight' : 'bold',
#         'size'   : 12}  # Increase font size for better readability
# plt.rc('font', **font)

# batches = 0
# for x, y in test_generator:
#     batches += 1
#     y_hat = final_model.predict(x, verbose=0)
#     x = np.squeeze(x)
#     if batches < 5:
#         plt.subplot(1, 5, batches)
#         plt.imshow(x[0])  # Displaying the first image in the batch
#         shape_pred_index = np.argmax(y[0])
#         type_pred_index = np.argmax(y_hat[1])
#         try:
#             shape_label = shapes_inv[shape_pred_index]
#         except KeyError:
#             shape_label = 'Unknown Shape'
#         try:
#             type_label = types_inv[type_pred_index]
#         except KeyError:
#             type_label = 'Unknown Type'
#         plt.title("Actual-{}, Pred-{}".format(shape_label, type_label), pad=20)  # Add padding to avoid overlap
#     else:
#         break

#     plt.axis('off')
# plt.tight_layout()  # Adjust layout to fit everything nicely
# plt.show()

# %% [markdown]
# ## 7. Conclusion

# %% [markdown]
# MLPs serve as a practical baseline for tasks like traffic sign classification due to their straightforward implementation and quick training. They are capable of modelling interactions between all input features, which is crucial for recognising complex patterns in the dataset. However, they are typically less effective than Convolutional Neural Networks (CNNs) for processing image data, as CNNs excel at capturing spatial hierarchies through their convolutional layers. This is evident from comparison tables where CNNs consistently show lower loss and higher accuracy.
# In conclusion, we think Model 2 (CNN) is superior.

# %% [markdown]
# # 8. References

# %% [markdown]
# - https://www.linkedin.com/pulse/classify-traffic-signs-deep-learning-james-medel/
# - https://github.com/james94/P3-Traffic-Sign-Classifier-CarND/blob/master/Traffic_Sign_Classifier_with_LeNet.ipynb
# - https://www.youtube.com/watch?v=jztwpsIzEGc
# - https://www.datacamp.com/tutorial/cnn-tensorflow-python
