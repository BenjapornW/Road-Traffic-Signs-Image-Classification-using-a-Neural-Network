# %% [markdown]
# # Project 1: Classify Images of Road Traffic Signs

# %% [markdown]
# ### Objective
# -  Identify and classify images of road traffic signs to enhance navigation systems and improve road safety

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
from google.colab import drive
drive .mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp /content/drive/'My Drive'/Assignment2/trafficsigns_dataset.zip .

# this directory is for Shina to connect to dataset and oil may need to offer github token so that we can both get the dataset from github repository
# format: !git clone https://username:token@github.com/username/repository.git

# !cp /content/drive/'My Drive'/COSC2673/Assignments/Assignment2/trafficsigns_dataset.zip .

# %% [markdown]
# Unzip the dataset

# %%
import zipfile
with zipfile.ZipFile('trafficsigns_dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('./')

# %% [markdown]
# #Collect Image Files
# - Function to traverse directories recursively and collect image files

# %%
def collect_image_files(directory):
    image_files = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith('.jpg') or file.endswith('.png'):
                image_files.append(os.path.join(root, file))
    return image_files

# %%
all_image_files = collect_image_files('./trafficsigns_dataset')

for image_file in all_image_files:
    print(image_file)
# Out:
# ./trafficsigns_dataset/diamond/rightofway/01112_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01111_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01526_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01933_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00938_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00192_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01244_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01112_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01569_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00192_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01238_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00192_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01111_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01254_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01715_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00118_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01933_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00123_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00959_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00063_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00037_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01519_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00032_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01244_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01889_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00952_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01911_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00050_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01909_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01254_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00121_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01889_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01673_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01248_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01502_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00208_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00039_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01957_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00935_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01511_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01270_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00068_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01108_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01803_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01883_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01514_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00222_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01753_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00111_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01656_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01237_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01656_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00065_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01102_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01955_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00045_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01528_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01873_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01702_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01955_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00547_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00045_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00044_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00935_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01883_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00103_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01713_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01253_00003.png
# ./trafficsigns_dataset/diamond/rightofway/01504_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01753_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00118_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01232_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00123_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00937_00003.png
# ./trafficsigns_dataset/diamond/rightofway/00208_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00060_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01805_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00046_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00050_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00121_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00928_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01243_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01959_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01911_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01886_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01002_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01524_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00931_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01930_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01012_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01745_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01957_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00111_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01231_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00930_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01231_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01502_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01715_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01745_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01013_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01243_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00935_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01013_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01526_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01753_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01237_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00123_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01959_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00042_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00928_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01569_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01275_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01262_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01276_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01528_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01249_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00046_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01253_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00118_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01713_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01248_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01102_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01519_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01511_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00951_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01249_00003.png
# ./trafficsigns_dataset/diamond/rightofway/00044_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00060_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00957_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01525_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00959_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00032_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00945_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01003_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01524_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01269_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01702_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01873_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01909_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01013_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01745_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00121_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01109_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01910_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01894_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01262_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00039_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01248_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00103_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00092_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01886_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01536_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01910_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01588_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01232_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00065_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01002_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01803_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01528_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01916_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00951_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00092_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01276_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01955_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01262_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01526_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01805_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01249_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01916_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00931_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01911_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00111_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01889_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01930_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00930_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00927_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01111_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01232_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00952_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01012_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01253_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00045_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01886_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00945_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00103_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01956_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00068_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00938_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00959_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00208_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00092_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01588_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00945_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00032_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01959_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01003_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00937_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00951_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01108_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00928_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01935_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01269_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01715_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01112_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01231_00003.png
# ./trafficsigns_dataset/diamond/rightofway/01238_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01525_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01803_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01514_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01514_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01894_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01275_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01588_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01109_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01894_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00037_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00930_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01536_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01238_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00044_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01933_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01253_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01956_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00050_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01536_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00931_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00937_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01108_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00943_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01263_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01263_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01002_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01269_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01249_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01957_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01276_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01916_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01275_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01673_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01935_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01805_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01254_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00937_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01231_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00039_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01519_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00957_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01237_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01263_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00042_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00943_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01930_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00952_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01909_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01102_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00222_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01935_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01012_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00063_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01956_00001.png
# ./trafficsigns_dataset/diamond/rightofway/00927_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01525_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01243_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01713_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01270_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01502_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01109_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01524_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00222_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00060_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01244_00000.png
# ./trafficsigns_dataset/diamond/rightofway/01873_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00065_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01910_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00042_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01883_00001.png
# ./trafficsigns_dataset/diamond/rightofway/01511_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01702_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00957_00002.png
# ./trafficsigns_dataset/diamond/rightofway/01003_00002.png
# ./trafficsigns_dataset/diamond/rightofway/00037_00000.png
# ./trafficsigns_dataset/diamond/rightofway/00063_00001.png
# ./trafficsigns_dataset/hex/stop/00546_00001.png
# ./trafficsigns_dataset/hex/stop/00478_00002.png
# ./trafficsigns_dataset/hex/stop/01951_00001.png
# ./trafficsigns_dataset/hex/stop/01811_00001.png
# ./trafficsigns_dataset/hex/stop/00684_00000.png
# ./trafficsigns_dataset/hex/stop/01920_00002.png
# ./trafficsigns_dataset/hex/stop/00554_00000.png
# ./trafficsigns_dataset/hex/stop/01162_00002.png
# ./trafficsigns_dataset/hex/stop/00715_00000.png
# ./trafficsigns_dataset/hex/stop/01832_00002.png
# ./trafficsigns_dataset/hex/stop/00375_00000.png
# ./trafficsigns_dataset/hex/stop/00375_00001.png
# ./trafficsigns_dataset/hex/stop/01258_00000.png
# ./trafficsigns_dataset/hex/stop/00685_00000.png
# ./trafficsigns_dataset/hex/stop/00478_00001.png
# ./trafficsigns_dataset/hex/stop/00375_00002.png
# ./trafficsigns_dataset/hex/stop/00715_00001.png
# ./trafficsigns_dataset/hex/stop/01811_00002.png
# ./trafficsigns_dataset/hex/stop/01162_00000.png
# ./trafficsigns_dataset/hex/stop/00554_00001.png
# ./trafficsigns_dataset/hex/stop/01951_00000.png
# ./trafficsigns_dataset/hex/stop/01162_00001.png
# ./trafficsigns_dataset/hex/stop/01832_00000.png
# ./trafficsigns_dataset/hex/stop/01811_00000.png
# ./trafficsigns_dataset/hex/stop/00684_00001.png
# ./trafficsigns_dataset/hex/stop/01258_00001.png
# ./trafficsigns_dataset/hex/stop/00685_00001.png
# ./trafficsigns_dataset/hex/stop/01868_00002.png
# ./trafficsigns_dataset/hex/stop/00546_00000.png
# ./trafficsigns_dataset/hex/stop/00715_00003.png
# ./trafficsigns_dataset/hex/stop/01832_00001.png
# ./trafficsigns_dataset/hex/stop/01951_00002.png
# ./trafficsigns_dataset/hex/stop/00685_00002.png
# ./trafficsigns_dataset/hex/stop/01868_00000.png
# ./trafficsigns_dataset/hex/stop/00684_00002.png
# ./trafficsigns_dataset/hex/stop/00478_00000.png
# ./trafficsigns_dataset/hex/stop/01920_00001.png
# ./trafficsigns_dataset/hex/stop/00715_00002.png
# ./trafficsigns_dataset/hex/stop/01258_00002.png
# ./trafficsigns_dataset/hex/stop/01920_00000.png
# ./trafficsigns_dataset/hex/stop/00554_00002.png
# ./trafficsigns_dataset/hex/stop/01868_00001.png
# ./trafficsigns_dataset/hex/stop/00546_00002.png
# ./trafficsigns_dataset/triangle/warning/00719_00002.png
# ./trafficsigns_dataset/triangle/warning/00202_00002.png
# ./trafficsigns_dataset/triangle/warning/01722_00001.png
# ./trafficsigns_dataset/triangle/warning/01081_00001.png
# ./trafficsigns_dataset/triangle/warning/01578_00000.png
# ./trafficsigns_dataset/triangle/warning/00262_00000.png
# ./trafficsigns_dataset/triangle/warning/00002_00000.png
# ./trafficsigns_dataset/triangle/warning/01433_00002.png
# ./trafficsigns_dataset/triangle/warning/01556_00001.png
# ./trafficsigns_dataset/triangle/warning/01080_00001.png
# ./trafficsigns_dataset/triangle/warning/01388_00000.png
# ./trafficsigns_dataset/triangle/warning/00298_00001.png
# ./trafficsigns_dataset/triangle/warning/01138_00001.png
# ./trafficsigns_dataset/triangle/warning/00876_00000.png
# ./trafficsigns_dataset/triangle/warning/01947_00002.png
# ./trafficsigns_dataset/triangle/warning/01850_00000.png
# ./trafficsigns_dataset/triangle/warning/00573_00000.png
# ./trafficsigns_dataset/triangle/warning/00992_00000.png
# ./trafficsigns_dataset/triangle/warning/00401_00000.png
# ./trafficsigns_dataset/triangle/warning/00406_00000.png
# ./trafficsigns_dataset/triangle/warning/01085_00000.png
# ./trafficsigns_dataset/triangle/warning/00017_00000.png
# ./trafficsigns_dataset/triangle/warning/00263_00002.png
# ./trafficsigns_dataset/triangle/warning/00454_00002.png
# ./trafficsigns_dataset/triangle/warning/01799_00002.png
# ./trafficsigns_dataset/triangle/warning/00326_00001.png
# ./trafficsigns_dataset/triangle/warning/01651_00000.png
# ./trafficsigns_dataset/triangle/warning/00365_00001.png
# ./trafficsigns_dataset/triangle/warning/01433_00001.png
# ./trafficsigns_dataset/triangle/warning/01083_00001.png
# ./trafficsigns_dataset/triangle/warning/01888_00000.png
# ./trafficsigns_dataset/triangle/warning/01663_00001.png
# ./trafficsigns_dataset/triangle/warning/00148_00001.png
# ./trafficsigns_dataset/triangle/warning/00379_00002.png
# ./trafficsigns_dataset/triangle/warning/00270_00000.png
# ./trafficsigns_dataset/triangle/warning/00221_00001.png
# ./trafficsigns_dataset/triangle/warning/00365_00002.png
# ./trafficsigns_dataset/triangle/warning/01199_00002.png
# ./trafficsigns_dataset/triangle/warning/00014_00001.png
# ./trafficsigns_dataset/triangle/warning/01397_00000.png
# ./trafficsigns_dataset/triangle/warning/00289_00001.png
# ./trafficsigns_dataset/triangle/warning/00024_00002.png
# ./trafficsigns_dataset/triangle/warning/00806_00000.png
# ./trafficsigns_dataset/triangle/warning/01662_00000.png
# ./trafficsigns_dataset/triangle/warning/00572_00001.png
# ./trafficsigns_dataset/triangle/warning/01393_00002.png
# ./trafficsigns_dataset/triangle/warning/01447_00001.png
# ./trafficsigns_dataset/triangle/warning/01880_00001.png
# ./trafficsigns_dataset/triangle/warning/00197_00000.png
# ./trafficsigns_dataset/triangle/warning/00401_00001.png
# ./trafficsigns_dataset/triangle/warning/00965_00002.png
# ./trafficsigns_dataset/triangle/warning/00178_00002.png
# ./trafficsigns_dataset/triangle/warning/00919_00002.png
# ./trafficsigns_dataset/triangle/warning/00769_00001.png
# ./trafficsigns_dataset/triangle/warning/01558_00002.png
# ./trafficsigns_dataset/triangle/warning/00429_00001.png
# ./trafficsigns_dataset/triangle/warning/00899_00002.png
# ./trafficsigns_dataset/triangle/warning/00211_00000.png
# ./trafficsigns_dataset/triangle/warning/01558_00001.png
# ./trafficsigns_dataset/triangle/warning/01077_00002.png
# ./trafficsigns_dataset/triangle/warning/01574_00001.png
# ./trafficsigns_dataset/triangle/warning/00262_00002.png
# ./trafficsigns_dataset/triangle/warning/01574_00000.png
# ./trafficsigns_dataset/triangle/warning/01160_00002.png
# ./trafficsigns_dataset/triangle/warning/01515_00001.png
# ./trafficsigns_dataset/triangle/warning/01530_00002.png
# ./trafficsigns_dataset/triangle/warning/00575_00002.png
# ./trafficsigns_dataset/triangle/warning/00068_00002.png
# ./trafficsigns_dataset/triangle/warning/01699_00000.png
# ./trafficsigns_dataset/triangle/warning/01135_00002.png
# ./trafficsigns_dataset/triangle/warning/00433_00002.png
# ./trafficsigns_dataset/triangle/warning/01393_00001.png
# ./trafficsigns_dataset/triangle/warning/00208_00000.png
# ./trafficsigns_dataset/triangle/warning/01794_00000.png
# ./trafficsigns_dataset/triangle/warning/01580_00001.png
# ./trafficsigns_dataset/triangle/warning/00859_00002.png
# ./trafficsigns_dataset/triangle/warning/00184_00002.png
# ./trafficsigns_dataset/triangle/warning/01704_00001.png
# ./trafficsigns_dataset/triangle/warning/01195_00001.png
# ./trafficsigns_dataset/triangle/warning/01490_00000.png
# ./trafficsigns_dataset/triangle/warning/01797_00000.png
# ./trafficsigns_dataset/triangle/warning/01062_00000.png
# ./trafficsigns_dataset/triangle/warning/00710_00001.png
# ./trafficsigns_dataset/triangle/warning/00017_00001.png
# ./trafficsigns_dataset/triangle/warning/01452_00000.png
# ./trafficsigns_dataset/triangle/warning/00068_00000.png
# ./trafficsigns_dataset/triangle/warning/01210_00000.png
# ./trafficsigns_dataset/triangle/warning/01521_00000.png
# ./trafficsigns_dataset/triangle/warning/01663_00000.png
# ./trafficsigns_dataset/triangle/warning/00211_00001.png
# ./trafficsigns_dataset/triangle/warning/01681_00002.png
# ./trafficsigns_dataset/triangle/warning/01135_00001.png
# ./trafficsigns_dataset/triangle/warning/01450_00000.png
# ./trafficsigns_dataset/triangle/warning/00132_00001.png
# ./trafficsigns_dataset/triangle/warning/01210_00001.png
# ./trafficsigns_dataset/triangle/warning/01195_00000.png
# ./trafficsigns_dataset/triangle/warning/00806_00002.png
# ./trafficsigns_dataset/triangle/warning/00920_00001.png
# ./trafficsigns_dataset/triangle/warning/01199_00000.png
# ./trafficsigns_dataset/triangle/warning/01447_00000.png
# ./trafficsigns_dataset/triangle/warning/01426_00001.png
# ./trafficsigns_dataset/triangle/warning/01114_00001.png
# ./trafficsigns_dataset/triangle/warning/01537_00001.png
# ./trafficsigns_dataset/triangle/warning/00910_00001.png
# ./trafficsigns_dataset/triangle/warning/00147_00001.png
# ./trafficsigns_dataset/triangle/warning/00709_00000.png
# ./trafficsigns_dataset/triangle/warning/01159_00001.png
# ./trafficsigns_dataset/triangle/warning/01515_00002.png
# ./trafficsigns_dataset/triangle/warning/01576_00002.png
# ./trafficsigns_dataset/triangle/warning/01651_00001.png
# ./trafficsigns_dataset/triangle/warning/00567_00000.png
# ./trafficsigns_dataset/triangle/warning/00575_00001.png
# ./trafficsigns_dataset/triangle/warning/00257_00001.png
# ./trafficsigns_dataset/triangle/warning/00143_00001.png
# ./trafficsigns_dataset/triangle/warning/00429_00000.png
# ./trafficsigns_dataset/triangle/warning/01388_00002.png
# ./trafficsigns_dataset/triangle/warning/00911_00002.png
# ./trafficsigns_dataset/triangle/warning/01798_00000.png
# ./trafficsigns_dataset/triangle/warning/00235_00000.png
# ./trafficsigns_dataset/triangle/warning/00448_00002.png
# ./trafficsigns_dataset/triangle/warning/01801_00000.png
# ./trafficsigns_dataset/triangle/warning/01016_00001.png
# ./trafficsigns_dataset/triangle/warning/00618_00000.png
# ./trafficsigns_dataset/triangle/warning/01556_00002.png
# ./trafficsigns_dataset/triangle/warning/01943_00002.png
# ./trafficsigns_dataset/triangle/warning/00145_00001.png
# ./trafficsigns_dataset/triangle/warning/00866_00000.png
# ./trafficsigns_dataset/triangle/warning/01873_00000.png
# ./trafficsigns_dataset/triangle/warning/00027_00001.png
# ./trafficsigns_dataset/triangle/warning/00196_00001.png
# ./trafficsigns_dataset/triangle/warning/00614_00002.png
# ./trafficsigns_dataset/triangle/warning/00025_00000.png
# ./trafficsigns_dataset/triangle/warning/01121_00000.png
# ./trafficsigns_dataset/triangle/warning/00298_00002.png
# ./trafficsigns_dataset/triangle/warning/01943_00000.png
# ./trafficsigns_dataset/triangle/warning/00987_00000.png
# ./trafficsigns_dataset/triangle/warning/01452_00002.png
# ./trafficsigns_dataset/triangle/warning/00675_00000.png
# ./trafficsigns_dataset/triangle/warning/00897_00002.png
# ./trafficsigns_dataset/triangle/warning/00748_00001.png
# ./trafficsigns_dataset/triangle/warning/00029_00000.png
# ./trafficsigns_dataset/triangle/warning/01850_00001.png
# ./trafficsigns_dataset/triangle/warning/00961_00000.png
# ./trafficsigns_dataset/triangle/warning/01722_00000.png
# ./trafficsigns_dataset/triangle/warning/00136_00001.png
# ./trafficsigns_dataset/triangle/warning/01926_00001.png
# ./trafficsigns_dataset/triangle/warning/01575_00002.png
# ./trafficsigns_dataset/triangle/warning/00196_00002.png
# ./trafficsigns_dataset/triangle/warning/01189_00002.png
# ./trafficsigns_dataset/triangle/warning/01544_00001.png
# ./trafficsigns_dataset/triangle/warning/00139_00002.png
# ./trafficsigns_dataset/triangle/warning/00078_00002.png
# ./trafficsigns_dataset/triangle/warning/00253_00000.png
# ./trafficsigns_dataset/triangle/warning/00289_00002.png
# ./trafficsigns_dataset/triangle/warning/00757_00000.png
# ./trafficsigns_dataset/triangle/warning/00014_00000.png
# ./trafficsigns_dataset/triangle/warning/00263_00001.png
# ./trafficsigns_dataset/triangle/warning/00201_00002.png
# ./trafficsigns_dataset/triangle/warning/01423_00000.png
# ./trafficsigns_dataset/triangle/warning/00208_00001.png
# ./trafficsigns_dataset/triangle/warning/00305_00000.png
# ./trafficsigns_dataset/triangle/warning/01114_00000.png
# ./trafficsigns_dataset/triangle/warning/00046_00001.png
# ./trafficsigns_dataset/triangle/warning/00025_00001.png
# ./trafficsigns_dataset/triangle/warning/01531_00001.png
# ./trafficsigns_dataset/triangle/warning/01585_00000.png
# ./trafficsigns_dataset/triangle/warning/01521_00001.png
# ./trafficsigns_dataset/triangle/warning/01880_00002.png
# ./trafficsigns_dataset/triangle/warning/00023_00000.png
# ./trafficsigns_dataset/triangle/warning/00078_00000.png
# ./trafficsigns_dataset/triangle/warning/01121_00001.png
# ./trafficsigns_dataset/triangle/warning/00057_00000.png
# ./trafficsigns_dataset/triangle/warning/01854_00002.png
# ./trafficsigns_dataset/triangle/warning/00365_00000.png
# ./trafficsigns_dataset/triangle/warning/00390_00000.png
# ./trafficsigns_dataset/triangle/warning/01017_00002.png
# ./trafficsigns_dataset/triangle/warning/01397_00002.png
# ./trafficsigns_dataset/triangle/warning/01590_00002.png
# ./trafficsigns_dataset/triangle/warning/01576_00000.png
# ./trafficsigns_dataset/triangle/warning/01016_00002.png
# ./trafficsigns_dataset/triangle/warning/00207_00000.png
# ./trafficsigns_dataset/triangle/warning/00235_00002.png
# ./trafficsigns_dataset/triangle/warning/00884_00002.png
# ./trafficsigns_dataset/triangle/warning/01585_00001.png
# ./trafficsigns_dataset/triangle/warning/01782_00002.png
# ./trafficsigns_dataset/triangle/warning/01471_00001.png
# ./trafficsigns_dataset/triangle/warning/00876_00001.png
# ./trafficsigns_dataset/triangle/warning/00324_00001.png
# ./trafficsigns_dataset/triangle/warning/00046_00002.png
# ./trafficsigns_dataset/triangle/warning/00207_00002.png
# ./trafficsigns_dataset/triangle/warning/01947_00000.png
# ./trafficsigns_dataset/triangle/warning/00307_00000.png
# ./trafficsigns_dataset/triangle/warning/01575_00001.png
# ./trafficsigns_dataset/triangle/warning/00259_00001.png
# ./trafficsigns_dataset/triangle/warning/01452_00001.png
# ./trafficsigns_dataset/triangle/warning/00260_00000.png
# ./trafficsigns_dataset/triangle/warning/00987_00001.png
# ./trafficsigns_dataset/triangle/warning/00874_00002.png
# ./trafficsigns_dataset/triangle/warning/01681_00001.png
# ./trafficsigns_dataset/triangle/warning/00327_00000.png
# ./trafficsigns_dataset/triangle/warning/00238_00000.png
# ./trafficsigns_dataset/triangle/warning/01681_00000.png
# ./trafficsigns_dataset/triangle/warning/00221_00002.png
# ./trafficsigns_dataset/triangle/warning/00770_00000.png
# ./trafficsigns_dataset/triangle/warning/00324_00002.png
# ./trafficsigns_dataset/triangle/warning/00261_00001.png
# ./trafficsigns_dataset/triangle/warning/01724_00001.png
# ./trafficsigns_dataset/triangle/warning/01312_00000.png
# ./trafficsigns_dataset/triangle/warning/00156_00001.png
# ./trafficsigns_dataset/triangle/warning/01531_00000.png
# ./trafficsigns_dataset/triangle/warning/00009_00001.png
# ./trafficsigns_dataset/triangle/warning/00874_00000.png
# ./trafficsigns_dataset/triangle/warning/00294_00002.png
# ./trafficsigns_dataset/triangle/warning/01653_00002.png
# ./trafficsigns_dataset/triangle/warning/00268_00000.png
# ./trafficsigns_dataset/triangle/warning/00024_00001.png
# ./trafficsigns_dataset/triangle/warning/01544_00000.png
# ./trafficsigns_dataset/triangle/warning/00270_00001.png
# ./trafficsigns_dataset/triangle/warning/00866_00002.png
# ./trafficsigns_dataset/triangle/warning/01075_00001.png
# ./trafficsigns_dataset/triangle/warning/00282_00000.png
# ./trafficsigns_dataset/triangle/warning/01780_00000.png
# ./trafficsigns_dataset/triangle/warning/01020_00001.png
# ./trafficsigns_dataset/triangle/warning/00961_00002.png
# ./trafficsigns_dataset/triangle/warning/00572_00000.png
# ./trafficsigns_dataset/triangle/warning/01724_00000.png
# ./trafficsigns_dataset/triangle/warning/00448_00001.png
# ./trafficsigns_dataset/triangle/warning/00305_00001.png
# ./trafficsigns_dataset/triangle/warning/00294_00001.png
# ./trafficsigns_dataset/triangle/warning/01520_00000.png
# ./trafficsigns_dataset/triangle/warning/00736_00002.png
# ./trafficsigns_dataset/triangle/warning/01103_00000.png
# ./trafficsigns_dataset/triangle/warning/00401_00002.png
# ./trafficsigns_dataset/triangle/warning/00289_00000.png
# ./trafficsigns_dataset/triangle/warning/00859_00001.png
# ./trafficsigns_dataset/triangle/warning/00390_00001.png
# ./trafficsigns_dataset/triangle/warning/01530_00000.png
# ./trafficsigns_dataset/triangle/warning/00178_00000.png
# ./trafficsigns_dataset/triangle/warning/01780_00001.png
# ./trafficsigns_dataset/triangle/warning/00394_00000.png
# ./trafficsigns_dataset/triangle/warning/00394_00001.png
# ./trafficsigns_dataset/triangle/warning/00623_00002.png
# ./trafficsigns_dataset/triangle/warning/00391_00001.png
# ./trafficsigns_dataset/triangle/warning/00023_00002.png
# ./trafficsigns_dataset/triangle/warning/00188_00000.png
# ./trafficsigns_dataset/triangle/warning/00238_00001.png
# ./trafficsigns_dataset/triangle/warning/00319_00001.png
# ./trafficsigns_dataset/triangle/warning/01221_00000.png
# ./trafficsigns_dataset/triangle/warning/01854_00001.png
# ./trafficsigns_dataset/triangle/warning/01549_00002.png
# ./trafficsigns_dataset/triangle/warning/01103_00001.png
# ./trafficsigns_dataset/triangle/warning/01291_00001.png
# ./trafficsigns_dataset/triangle/warning/00195_00000.png
# ./trafficsigns_dataset/triangle/warning/01138_00002.png
# ./trafficsigns_dataset/triangle/warning/01662_00002.png
# ./trafficsigns_dataset/triangle/warning/01503_00002.png
# ./trafficsigns_dataset/triangle/warning/00184_00000.png
# ./trafficsigns_dataset/triangle/warning/00138_00000.png
# ./trafficsigns_dataset/triangle/warning/00270_00002.png
# ./trafficsigns_dataset/triangle/warning/00299_00000.png
# ./trafficsigns_dataset/triangle/warning/00145_00000.png
# ./trafficsigns_dataset/triangle/warning/01537_00002.png
# ./trafficsigns_dataset/triangle/warning/00866_00001.png
# ./trafficsigns_dataset/triangle/warning/00757_00002.png
# ./trafficsigns_dataset/triangle/warning/00299_00002.png
# ./trafficsigns_dataset/triangle/warning/00371_00001.png
# ./trafficsigns_dataset/triangle/warning/00014_00002.png
# ./trafficsigns_dataset/triangle/warning/00675_00001.png
# ./trafficsigns_dataset/triangle/warning/00252_00000.png
# ./trafficsigns_dataset/triangle/warning/00573_00002.png
# ./trafficsigns_dataset/triangle/warning/00023_00001.png
# ./trafficsigns_dataset/triangle/warning/00220_00002.png
# ./trafficsigns_dataset/triangle/warning/00391_00002.png
# ./trafficsigns_dataset/triangle/warning/00132_00000.png
# ./trafficsigns_dataset/triangle/warning/00406_00001.png
# ./trafficsigns_dataset/triangle/warning/01578_00001.png
# ./trafficsigns_dataset/triangle/warning/00046_00000.png
# ./trafficsigns_dataset/triangle/warning/00240_00002.png
# ./trafficsigns_dataset/triangle/warning/01925_00001.png
# ./trafficsigns_dataset/triangle/warning/01531_00002.png
# ./trafficsigns_dataset/triangle/warning/01466_00000.png
# ./trafficsigns_dataset/triangle/warning/01682_00002.png
# ./trafficsigns_dataset/triangle/warning/01893_00002.png
# ./trafficsigns_dataset/triangle/warning/00781_00001.png
# ./trafficsigns_dataset/triangle/warning/00221_00000.png
# ./trafficsigns_dataset/triangle/warning/00025_00002.png
# ./trafficsigns_dataset/triangle/warning/00947_00001.png
# ./trafficsigns_dataset/triangle/warning/00877_00000.png
# ./trafficsigns_dataset/triangle/warning/00009_00002.png
# ./trafficsigns_dataset/triangle/warning/00017_00002.png
# ./trafficsigns_dataset/triangle/warning/00326_00002.png
# ./trafficsigns_dataset/triangle/warning/00254_00000.png
# ./trafficsigns_dataset/triangle/warning/00881_00000.png
# ./trafficsigns_dataset/triangle/warning/00282_00002.png
# ./trafficsigns_dataset/triangle/warning/00736_00000.png
# ./trafficsigns_dataset/triangle/warning/00468_00000.png
# ./trafficsigns_dataset/triangle/warning/00008_00001.png
# ./trafficsigns_dataset/triangle/warning/00567_00001.png
# ./trafficsigns_dataset/triangle/warning/00215_00000.png
# ./trafficsigns_dataset/triangle/warning/01699_00002.png
# ./trafficsigns_dataset/triangle/warning/01682_00000.png
# ./trafficsigns_dataset/triangle/warning/01189_00001.png
# ./trafficsigns_dataset/triangle/warning/00455_00000.png
# ./trafficsigns_dataset/triangle/warning/00781_00002.png
# ./trafficsigns_dataset/triangle/warning/00475_00001.png
# ./trafficsigns_dataset/triangle/warning/01153_00001.png
# ./trafficsigns_dataset/triangle/warning/00331_00000.png
# ./trafficsigns_dataset/triangle/warning/01574_00002.png
# ./trafficsigns_dataset/triangle/warning/00941_00000.png
# ./trafficsigns_dataset/triangle/warning/01576_00001.png
# ./trafficsigns_dataset/triangle/warning/01640_00001.png
# ./trafficsigns_dataset/triangle/warning/00254_00002.png
# ./trafficsigns_dataset/triangle/warning/00920_00000.png
# ./trafficsigns_dataset/triangle/warning/01926_00000.png
# ./trafficsigns_dataset/triangle/warning/01152_00002.png
# ./trafficsigns_dataset/triangle/warning/00148_00000.png
# ./trafficsigns_dataset/triangle/warning/00235_00001.png
# ./trafficsigns_dataset/triangle/warning/00214_00001.png
# ./trafficsigns_dataset/triangle/warning/00295_00001.png
# ./trafficsigns_dataset/triangle/warning/00408_00000.png
# ./trafficsigns_dataset/triangle/warning/01020_00002.png
# ./trafficsigns_dataset/triangle/warning/01780_00002.png
# ./trafficsigns_dataset/triangle/warning/01406_00001.png
# ./trafficsigns_dataset/triangle/warning/01061_00001.png
# ./trafficsigns_dataset/triangle/warning/01926_00002.png
# ./trafficsigns_dataset/triangle/warning/00201_00001.png
# ./trafficsigns_dataset/triangle/warning/00138_00001.png
# ./trafficsigns_dataset/triangle/warning/00468_00001.png
# ./trafficsigns_dataset/triangle/warning/00689_00003.png
# ./trafficsigns_dataset/triangle/warning/01873_00001.png
# ./trafficsigns_dataset/triangle/warning/00550_00000.png
# ./trafficsigns_dataset/triangle/warning/01520_00002.png
# ./trafficsigns_dataset/triangle/warning/01704_00000.png
# ./trafficsigns_dataset/triangle/warning/00252_00001.png
# ./trafficsigns_dataset/triangle/warning/01186_00002.png
# ./trafficsigns_dataset/triangle/warning/00214_00000.png
# ./trafficsigns_dataset/triangle/warning/00268_00001.png
# ./trafficsigns_dataset/triangle/warning/00897_00001.png
# ./trafficsigns_dataset/triangle/warning/00201_00000.png
# ./trafficsigns_dataset/triangle/warning/00394_00002.png
# ./trafficsigns_dataset/triangle/warning/01888_00002.png
# ./trafficsigns_dataset/triangle/warning/00327_00002.png
# ./trafficsigns_dataset/triangle/warning/00919_00000.png
# ./trafficsigns_dataset/triangle/warning/01159_00002.png
# ./trafficsigns_dataset/triangle/warning/00455_00002.png
# ./trafficsigns_dataset/triangle/warning/00859_00000.png
# ./trafficsigns_dataset/triangle/warning/00211_00002.png
# ./trafficsigns_dataset/triangle/warning/00719_00000.png
# ./trafficsigns_dataset/triangle/warning/01530_00001.png
# ./trafficsigns_dataset/triangle/warning/01585_00002.png
# ./trafficsigns_dataset/triangle/warning/00307_00002.png
# ./trafficsigns_dataset/triangle/warning/00921_00000.png
# ./trafficsigns_dataset/triangle/warning/01028_00000.png
# ./trafficsigns_dataset/triangle/warning/00299_00001.png
# ./trafficsigns_dataset/triangle/warning/01598_00002.png
# ./trafficsigns_dataset/triangle/warning/01388_00001.png
# ./trafficsigns_dataset/triangle/warning/00869_00002.png
# ./trafficsigns_dataset/triangle/warning/01186_00000.png
# ./trafficsigns_dataset/triangle/warning/00884_00000.png
# ./trafficsigns_dataset/triangle/warning/01584_00002.png
# ./trafficsigns_dataset/triangle/warning/00468_00002.png
# ./trafficsigns_dataset/triangle/warning/00737_00000.png
# ./trafficsigns_dataset/triangle/warning/01653_00000.png
# ./trafficsigns_dataset/triangle/warning/00429_00002.png
# ./trafficsigns_dataset/triangle/warning/01061_00000.png
# ./trafficsigns_dataset/triangle/warning/00220_00000.png
# ./trafficsigns_dataset/triangle/warning/00454_00001.png
# ./trafficsigns_dataset/triangle/warning/00249_00002.png
# ./trafficsigns_dataset/triangle/warning/01584_00000.png
# ./trafficsigns_dataset/triangle/warning/01135_00000.png
# ./trafficsigns_dataset/triangle/warning/00933_00000.png
# ./trafficsigns_dataset/triangle/warning/00139_00001.png
# ./trafficsigns_dataset/triangle/warning/00623_00001.png
# ./trafficsigns_dataset/triangle/warning/01485_00001.png
# ./trafficsigns_dataset/triangle/warning/00079_00002.png
# ./trafficsigns_dataset/triangle/warning/01077_00000.png
# ./trafficsigns_dataset/triangle/warning/01152_00001.png
# ./trafficsigns_dataset/triangle/warning/01549_00001.png
# ./trafficsigns_dataset/triangle/warning/01153_00000.png
# ./trafficsigns_dataset/triangle/warning/01575_00000.png
# ./trafficsigns_dataset/triangle/warning/01339_00000.png
# ./trafficsigns_dataset/triangle/warning/00248_00002.png
# ./trafficsigns_dataset/triangle/warning/00327_00001.png
# ./trafficsigns_dataset/triangle/warning/01903_00002.png
# ./trafficsigns_dataset/triangle/warning/00769_00000.png
# ./trafficsigns_dataset/triangle/warning/00143_00002.png
# ./trafficsigns_dataset/triangle/warning/00845_00000.png
# ./trafficsigns_dataset/triangle/warning/00877_00002.png
# ./trafficsigns_dataset/triangle/warning/00240_00000.png
# ./trafficsigns_dataset/triangle/warning/01016_00000.png
# ./trafficsigns_dataset/triangle/warning/01450_00001.png
# ./trafficsigns_dataset/triangle/warning/01139_00001.png
# ./trafficsigns_dataset/triangle/warning/00806_00001.png
# ./trafficsigns_dataset/triangle/warning/00147_00002.png
# ./trafficsigns_dataset/triangle/warning/01076_00000.png
# ./trafficsigns_dataset/triangle/warning/00965_00001.png
# ./trafficsigns_dataset/triangle/warning/00008_00000.png
# ./trafficsigns_dataset/triangle/warning/00406_00002.png
# ./trafficsigns_dataset/triangle/warning/01393_00000.png
# ./trafficsigns_dataset/triangle/warning/01598_00000.png
# ./trafficsigns_dataset/triangle/warning/00220_00001.png
# ./trafficsigns_dataset/triangle/warning/00148_00002.png
# ./trafficsigns_dataset/triangle/warning/00024_00000.png
# ./trafficsigns_dataset/triangle/warning/01199_00001.png
# ./trafficsigns_dataset/triangle/warning/00202_00001.png
# ./trafficsigns_dataset/triangle/warning/01087_00002.png
# ./trafficsigns_dataset/triangle/warning/00215_00002.png
# ./trafficsigns_dataset/triangle/warning/01086_00001.png
# ./trafficsigns_dataset/triangle/warning/01880_00000.png
# ./trafficsigns_dataset/triangle/warning/01503_00001.png
# ./trafficsigns_dataset/triangle/warning/00408_00002.png
# ./trafficsigns_dataset/triangle/warning/00057_00001.png
# ./trafficsigns_dataset/triangle/warning/00992_00002.png
# ./trafficsigns_dataset/triangle/warning/00263_00000.png
# ./trafficsigns_dataset/triangle/warning/01971_00000.png
# ./trafficsigns_dataset/triangle/warning/00147_00000.png
# ./trafficsigns_dataset/triangle/warning/01028_00002.png
# ./trafficsigns_dataset/triangle/warning/00748_00000.png
# ./trafficsigns_dataset/triangle/warning/00845_00002.png
# ./trafficsigns_dataset/triangle/warning/01085_00001.png
# ./trafficsigns_dataset/triangle/warning/01139_00002.png
# ./trafficsigns_dataset/triangle/warning/01590_00001.png
# ./trafficsigns_dataset/triangle/warning/00881_00001.png
# ./trafficsigns_dataset/triangle/warning/00433_00001.png
# ./trafficsigns_dataset/triangle/warning/00689_00001.png
# ./trafficsigns_dataset/triangle/warning/00910_00002.png
# ./trafficsigns_dataset/triangle/warning/01490_00001.png
# ./trafficsigns_dataset/triangle/warning/00371_00002.png
# ./trafficsigns_dataset/triangle/warning/01925_00000.png
# ./trafficsigns_dataset/triangle/warning/00259_00002.png
# ./trafficsigns_dataset/triangle/warning/00737_00001.png
# ./trafficsigns_dataset/triangle/warning/00899_00001.png
# ./trafficsigns_dataset/triangle/warning/01471_00002.png
# ./trafficsigns_dataset/triangle/warning/00240_00001.png
# ./trafficsigns_dataset/triangle/warning/00197_00002.png
# ./trafficsigns_dataset/triangle/warning/00379_00001.png
# ./trafficsigns_dataset/triangle/warning/00614_00000.png
# ./trafficsigns_dataset/triangle/warning/00027_00000.png
# ./trafficsigns_dataset/triangle/warning/01556_00000.png
# ./trafficsigns_dataset/triangle/warning/01584_00001.png
# ./trafficsigns_dataset/triangle/warning/00214_00002.png
# ./trafficsigns_dataset/triangle/warning/00195_00001.png
# ./trafficsigns_dataset/triangle/warning/00002_00001.png
# ./trafficsigns_dataset/triangle/warning/01662_00001.png
# ./trafficsigns_dataset/triangle/warning/01062_00001.png
# ./trafficsigns_dataset/triangle/warning/01580_00000.png
# ./trafficsigns_dataset/triangle/warning/01062_00002.png
# ./trafficsigns_dataset/triangle/warning/00919_00001.png
# ./trafficsigns_dataset/triangle/warning/00737_00002.png
# ./trafficsigns_dataset/triangle/warning/01159_00000.png
# ./trafficsigns_dataset/triangle/warning/01794_00001.png
# ./trafficsigns_dataset/triangle/warning/00371_00000.png
# ./trafficsigns_dataset/triangle/warning/00379_00000.png
# ./trafficsigns_dataset/triangle/warning/01152_00000.png
# ./trafficsigns_dataset/triangle/warning/01278_00002.png
# ./trafficsigns_dataset/triangle/warning/01521_00002.png
# ./trafficsigns_dataset/triangle/warning/01291_00002.png
# ./trafficsigns_dataset/triangle/warning/00207_00001.png
# ./trafficsigns_dataset/triangle/warning/00257_00002.png
# ./trafficsigns_dataset/triangle/warning/00057_00002.png
# ./trafficsigns_dataset/triangle/warning/00801_00002.png
# ./trafficsigns_dataset/triangle/warning/01081_00000.png
# ./trafficsigns_dataset/triangle/warning/01076_00001.png
# ./trafficsigns_dataset/triangle/warning/01797_00001.png
# ./trafficsigns_dataset/triangle/warning/01114_00002.png
# ./trafficsigns_dataset/triangle/warning/00238_00002.png
# ./trafficsigns_dataset/triangle/warning/00259_00000.png
# ./trafficsigns_dataset/triangle/warning/00408_00001.png
# ./trafficsigns_dataset/triangle/warning/01704_00002.png
# ./trafficsigns_dataset/triangle/warning/00215_00001.png
# ./trafficsigns_dataset/triangle/warning/01075_00000.png
# ./trafficsigns_dataset/triangle/warning/00178_00001.png
# ./trafficsigns_dataset/triangle/warning/01903_00001.png
# ./trafficsigns_dataset/triangle/warning/00196_00000.png
# ./trafficsigns_dataset/triangle/warning/00268_00002.png
# ./trafficsigns_dataset/triangle/warning/01406_00000.png
# ./trafficsigns_dataset/triangle/warning/00051_00001.png
# ./trafficsigns_dataset/triangle/warning/01103_00002.png
# ./trafficsigns_dataset/triangle/warning/00254_00001.png
# ./trafficsigns_dataset/triangle/warning/00572_00002.png
# ./trafficsigns_dataset/triangle/warning/00689_00000.png
# ./trafficsigns_dataset/triangle/warning/00874_00001.png
# ./trafficsigns_dataset/triangle/warning/00068_00001.png
# ./trafficsigns_dataset/triangle/warning/00331_00001.png
# ./trafficsigns_dataset/triangle/warning/00208_00002.png
# ./trafficsigns_dataset/triangle/warning/00138_00002.png
# ./trafficsigns_dataset/triangle/warning/01605_00002.png
# ./trafficsigns_dataset/triangle/warning/00675_00002.png
# ./trafficsigns_dataset/triangle/warning/01426_00000.png
# ./trafficsigns_dataset/triangle/warning/00188_00002.png
# ./trafficsigns_dataset/triangle/warning/00305_00002.png
# ./trafficsigns_dataset/triangle/warning/00911_00001.png
# ./trafficsigns_dataset/triangle/warning/01139_00000.png
# ./trafficsigns_dataset/triangle/warning/01801_00002.png
# ./trafficsigns_dataset/triangle/warning/01195_00002.png
# ./trafficsigns_dataset/triangle/warning/01080_00000.png
# ./trafficsigns_dataset/triangle/warning/01651_00002.png
# ./trafficsigns_dataset/triangle/warning/01700_00000.png
# ./trafficsigns_dataset/triangle/warning/00184_00001.png
# ./trafficsigns_dataset/triangle/warning/00623_00000.png
# ./trafficsigns_dataset/triangle/warning/00769_00002.png
# ./trafficsigns_dataset/triangle/warning/00933_00001.png
# ./trafficsigns_dataset/triangle/warning/01426_00002.png
# ./trafficsigns_dataset/triangle/warning/01083_00000.png
# ./trafficsigns_dataset/triangle/warning/01160_00000.png
# ./trafficsigns_dataset/triangle/warning/00781_00000.png
# ./trafficsigns_dataset/triangle/warning/00079_00000.png
# ./trafficsigns_dataset/triangle/warning/01549_00000.png
# ./trafficsigns_dataset/triangle/warning/01447_00002.png
# ./trafficsigns_dataset/triangle/warning/01017_00000.png
# ./trafficsigns_dataset/triangle/warning/00391_00000.png
# ./trafficsigns_dataset/triangle/warning/01466_00001.png
# ./trafficsigns_dataset/triangle/warning/01782_00001.png
# ./trafficsigns_dataset/triangle/warning/00899_00000.png
# ./trafficsigns_dataset/triangle/warning/00249_00000.png
# ./trafficsigns_dataset/triangle/warning/01903_00000.png
# ./trafficsigns_dataset/triangle/warning/00933_00002.png
# ./trafficsigns_dataset/triangle/warning/00736_00001.png
# ./trafficsigns_dataset/triangle/warning/01221_00001.png
# ./trafficsigns_dataset/triangle/warning/01406_00002.png
# ./trafficsigns_dataset/triangle/warning/00877_00001.png
# ./trafficsigns_dataset/triangle/warning/00029_00002.png
# ./trafficsigns_dataset/triangle/warning/01947_00001.png
# ./trafficsigns_dataset/triangle/warning/01682_00001.png
# ./trafficsigns_dataset/triangle/warning/01061_00002.png
# ./trafficsigns_dataset/triangle/warning/01544_00002.png
# ./trafficsigns_dataset/triangle/warning/01801_00001.png
# ./trafficsigns_dataset/triangle/warning/01076_00002.png
# ...
# ./trafficsigns_dataset/round/bicycle/01208_00000.png
# ./trafficsigns_dataset/round/bicycle/00446_00001.png
# ./trafficsigns_dataset/round/bicycle/00171_00002.png
# ./trafficsigns_dataset/round/bicycle/00732_00000.png
# ./trafficsigns_dataset/round/bicycle/00741_00001.png
# ./trafficsigns_dataset/round/bicycle/00694_00001.png
# ./trafficsigns_dataset/round/bicycle/01129_00001.png
# ./trafficsigns_dataset/round/bicycle/01847_00002.png
# ./trafficsigns_dataset/round/bicycle/00452_00000.png
# ./trafficsigns_dataset/round/bicycle/00778_00000.png
# ./trafficsigns_dataset/round/bicycle/00796_00002.png
# ./trafficsigns_dataset/round/bicycle/01840_00000.png
# ./trafficsigns_dataset/round/bicycle/00434_00001.png
# ./trafficsigns_dataset/round/bicycle/00059_00002.png
# ./trafficsigns_dataset/round/bicycle/01954_00002.png
# ./trafficsigns_dataset/round/bicycle/00453_00000.png
# ./trafficsigns_dataset/round/bicycle/00796_00001.png
# ./trafficsigns_dataset/round/bicycle/00574_00001.png
# ./trafficsigns_dataset/round/bicycle/00392_00002.png
# ./trafficsigns_dataset/round/bicycle/00453_00001.png
# ./trafficsigns_dataset/round/bicycle/01347_00001.png
# ./trafficsigns_dataset/round/bicycle/01963_00001.png
# ./trafficsigns_dataset/round/bicycle/00075_00001.png
# ./trafficsigns_dataset/round/bicycle/01315_00001.png
# ./trafficsigns_dataset/round/bicycle/01846_00000.png
# ./trafficsigns_dataset/round/bicycle/00774_00001.png
# ./trafficsigns_dataset/round/bicycle/00438_00001.png
# ./trafficsigns_dataset/round/bicycle/00061_00002.png
# ./trafficsigns_dataset/round/bicycle/00740_00001.png
# ./trafficsigns_dataset/round/bicycle/01364_00002.png
# ./trafficsigns_dataset/round/bicycle/01110_00002.png
# ./trafficsigns_dataset/round/bicycle/00822_00001.png
# ./trafficsigns_dataset/round/bicycle/00862_00001.png
# ./trafficsigns_dataset/round/bicycle/00740_00002.png
# ./trafficsigns_dataset/round/bicycle/00473_00002.png
# ./trafficsigns_dataset/round/bicycle/00864_00000.png
# ./trafficsigns_dataset/round/bicycle/01110_00000.png
# ./trafficsigns_dataset/round/bicycle/00448_00000.png
# ./trafficsigns_dataset/round/bicycle/01034_00000.png
# ./trafficsigns_dataset/round/bicycle/01129_00000.png
# ./trafficsigns_dataset/round/bicycle/00822_00000.png
# ./trafficsigns_dataset/round/bicycle/00857_00002.png
# ./trafficsigns_dataset/round/bicycle/01960_00000.png
# ./trafficsigns_dataset/round/bicycle/01364_00000.png
# ./trafficsigns_dataset/round/bicycle/00418_00002.png
# ./trafficsigns_dataset/round/bicycle/01382_00001.png
# ./trafficsigns_dataset/round/bicycle/00677_00002.png
# ./trafficsigns_dataset/round/bicycle/00075_00000.png
# ./trafficsigns_dataset/round/bicycle/01029_00002.png
# ./trafficsigns_dataset/round/bicycle/00004_00002.png
# ./trafficsigns_dataset/round/bicycle/00438_00002.png
# ./trafficsigns_dataset/round/bicycle/01846_00002.png
# ./trafficsigns_dataset/round/bicycle/01461_00002.png
# ./trafficsigns_dataset/round/bicycle/01342_00002.png
# ./trafficsigns_dataset/round/bicycle/00861_00001.png
# ./trafficsigns_dataset/round/bicycle/00740_00000.png
# ./trafficsigns_dataset/round/bicycle/00855_00001.png
# ./trafficsigns_dataset/round/bicycle/01713_00001.png
# ./trafficsigns_dataset/round/bicycle/01208_00002.png
# ./trafficsigns_dataset/round/bicycle/01502_00002.png
# ./trafficsigns_dataset/round/bicycle/00655_00002.png
# ./trafficsigns_dataset/round/bicycle/00418_00001.png
# ./trafficsigns_dataset/round/bicycle/00862_00002.png
# ./trafficsigns_dataset/round/bicycle/00686_00000.png
# ./trafficsigns_dataset/round/bicycle/01954_00001.png
# ./trafficsigns_dataset/round/bicycle/00004_00001.png
# ./trafficsigns_dataset/round/bicycle/01208_00001.png
# ./trafficsigns_dataset/round/bicycle/00800_00000.png
# ./trafficsigns_dataset/round/bicycle/00655_00000.png
# ./trafficsigns_dataset/round/bicycle/01511_00002.png
# ./trafficsigns_dataset/round/bicycle/01351_00001.png
# ./trafficsigns_dataset/round/bicycle/00857_00000.png
# ./trafficsigns_dataset/round/bicycle/01457_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01693_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01693_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01968_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00231_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00909_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01174_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00465_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00673_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00469_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01151_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01151_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00118_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00630_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00063_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01716_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01911_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00050_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00068_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01970_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01909_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01836_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01699_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01957_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00535_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00230_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00332_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00068_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00111_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01174_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01166_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00065_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01755_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00465_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01970_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01955_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00272_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01968_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01955_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00103_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00908_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00118_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01657_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01175_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01183_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01176_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01496_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00332_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00060_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00050_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01959_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00231_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01834_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01911_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01855_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00650_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01184_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01865_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01957_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00111_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01594_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01970_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01900_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00701_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01855_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00650_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00673_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01365_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00230_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00696_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01175_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01836_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01859_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01959_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00021_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01657_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01865_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01925_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00272_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00908_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00118_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00469_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00535_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01699_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00060_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00230_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01174_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01541_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00701_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01909_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01910_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01894_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01367_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00103_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00092_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01181_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01910_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00021_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00630_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01365_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00065_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00699_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01916_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00092_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01834_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01955_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01184_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01836_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00332_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01716_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01916_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00376_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00535_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01925_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00699_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01496_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01911_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00111_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00673_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00272_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01183_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00413_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00465_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00103_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01956_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00068_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00092_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01959_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00275_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01859_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00231_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01755_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01657_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01855_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00650_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01900_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00413_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01894_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01541_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00909_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01925_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01894_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01859_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01699_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00785_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01184_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00630_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01834_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01594_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00701_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01956_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00275_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00050_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00908_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01175_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01957_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01693_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01166_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01916_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00699_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01151_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01865_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00469_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01594_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01496_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01181_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01181_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01176_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01367_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00785_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00696_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00413_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01176_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00696_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01909_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00785_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01541_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00063_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00909_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01956_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00275_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01365_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01183_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01716_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01367_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01968_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01166_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00060_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00376_00000.png
# ./trafficsigns_dataset/round/trafficdirective/00065_00001.png
# ./trafficsigns_dataset/round/trafficdirective/01910_00002.png
# ./trafficsigns_dataset/round/trafficdirective/01900_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00376_00001.png
# ./trafficsigns_dataset/round/trafficdirective/00021_00000.png
# ./trafficsigns_dataset/round/trafficdirective/01755_00002.png
# ./trafficsigns_dataset/round/trafficdirective/00063_00001.png

# %%
# Create a DataFrame with image file paths in a column named 'image_path'
df = pd.DataFrame({'image_path': all_image_files})

# %%
trafficsigns_shapes = {'diamond': 0, 'hex': 1, 'round': 2, 'square': 3, 'triangle': 4}
trafficsigns_types = {'rightofway': 0, 'stop': 1, 'bicycle': 2, 'limitedtraffic': 3, 'noentry': 4, 'noparking': 5,
                      'roundabout':6, 'speed': 7, 'trafficdirective': 8, 'traveldirection': 9, 'continue': 10,
                      'crossing': 11,  'laneend': 12, 'parking': 13, 'giveway': 14, 'warning': 15}

# %% [markdown]
# This project involves **multi-class image classification** and features traffic signs categorised into 5 shape classes and 16 type classes, with each image being classified into one of these categories

# %%
def assign_class_label(image_path):
    # Split the image path by '/'
    parts = image_path.split('/')

    # Extract shape and type from the parts
    shape = parts[-3]
    trafficsign_type = parts[-2]

    # Map shape and type to corresponding class labels using the dictionaries
    shape_label = trafficsigns_shapes.get(shape, -1)  # -1 if shape not found in dictionary
    type_label = trafficsigns_types.get(trafficsign_type, -1)  # -1 if type not found in dictionary

    # Return a tuple of shape label and type label
    return (shape_label, type_label)

# %% [markdown]
# - Get the dataframe with image_path, shape_label and type_label

# %%
df['shape_label'], df['type_label'] = zip(*df['image_path'].apply(assign_class_label))

# %%
df
# Out:
#                                              image_path  shape_label  \
# 0     ./trafficsigns_dataset/diamond/rightofway/0111...            0
# 1     ./trafficsigns_dataset/diamond/rightofway/0111...            0
# 2     ./trafficsigns_dataset/diamond/rightofway/0152...            0
# 3     ./trafficsigns_dataset/diamond/rightofway/0193...            0
# 4     ./trafficsigns_dataset/diamond/rightofway/0093...            0
# ...                                                 ...          ...
# 3694  ./trafficsigns_dataset/round/trafficdirective/...            2
# 3695  ./trafficsigns_dataset/round/trafficdirective/...            2
# 3696  ./trafficsigns_dataset/round/trafficdirective/...            2
# 3697  ./trafficsigns_dataset/round/trafficdirective/...            2
# 3698  ./trafficsigns_dataset/round/trafficdirective/...            2
#
#       type_label
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 3694           8
# 3695           8
# 3696           8
# 3697           8
# 3698           8
#
# [3699 rows x 3 columns]

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
from matplotlib.pyplot import imread
import imageio

# # Now you have 'shape_label' and 'type_label' as separate columns
# # We'll concatenate these labels to create a unique identifier for each class combination


df['class_combo'] = df[['shape_label', 'type_label']].apply(tuple, axis=1)

# Reverse dictionaries to map labels back to names
shape_names = {v: k for k, v in trafficsigns_shapes.items()}
type_names = {v: k for k, v in trafficsigns_types.items()}

# Group by this new combo and pick the first image from each group
grouped = df.groupby('class_combo').first().reset_index()

# Visualization
plt.figure(figsize=(16, 16))
for i, row in enumerate(grouped.itertuples(), 1):
    plt.subplot(4, 4, i)  # Adjust grid size based on the number of unique class combinations
    image_path = os.path.join(os.getcwd(), row.image_path)
    image = imread(image_path)
    # Look up the shape and type names using the reverse dictionaries
    shape_name = shape_names.get(row.shape_label, "Unknown")
    type_name = type_names.get(row.type_label, "Unknown")
    plt.imshow(image)
    plt.axis('off')
    plt.title(f"Shape: {shape_name} ({row.shape_label}), Type: {type_name} ({row.type_label})", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Dataset

# %% [markdown]
# Source: Belgium Traffic Sign Classification Benchmark, German TSC dataset
#
# Input variables:
#
# Output variable (desired target):

# %% [markdown]
# # Distribution of the dataset

# %%
import matplotlib.pyplot as plt


# Convert index to label name for shapes
shape_labels = [f'{k} ({v})' for k, v in sorted(trafficsigns_shapes.items(), key=lambda item: item[1])]
# Convert index to label name for types
type_labels = [f'{k} ({v})' for k, v in sorted(trafficsigns_types.items(), key=lambda item: item[1])]

# Calculate the count of each class label for shape and type
shape_counts = df['shape_label'].value_counts().sort_index()
type_counts = df['type_label'].value_counts().sort_index()

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 5))

# Bar chart for shape labels
axes[0].bar(shape_labels, shape_counts.values, color='#8367c7')
axes[0].set_title('Number of Images per Shape Class')
axes[0].set_xlabel('Shape Class Label')
axes[0].set_ylabel('Number of Images')
axes[0].set_xticklabels(shape_labels, rotation=45, ha='right')
for index, value in enumerate(shape_counts.values):
    axes[0].text(index, value, str(value), ha='center')

# Bar chart for type labels
axes[1].bar(type_labels, type_counts.values, color='#C2F8CB')
axes[1].set_title('Number of Images per Type Class')
axes[1].set_xlabel('Type Class Label')
axes[1].set_ylabel('Number of Images')
axes[1].set_xticklabels(type_labels, rotation=45, ha='right')
for index, value in enumerate(type_counts.values):
    axes[1].text(index, value, str(value), ha='center')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-269-2dc661fc10c5>:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0].set_xticklabels(shape_labels, rotation=45, ha='right')
# <ipython-input-269-2dc661fc10c5>:29: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[1].set_xticklabels(type_labels, rotation=45, ha='right')

# %% [markdown]
# ## Data Spliting
# - split them with 2 outputs

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(df, test_size=0.2, random_state=42)
train_data, val_data = train_test_split(train_data, test_size=0.25, random_state=42)

print("Train data : {}, Val Data: {}, Test Data: {}".format(train_data.shape[0], val_data.shape[0], test_data.shape[0]))
# Out:
# Train data : 2219, Val Data: 740, Test Data: 740

# %%
train_data.shape
# Out:
# (2219, 4)

# %%
# Print column names to verify
print(train_data.columns)
# Out:
# Index(['image_path', 'shape_label', 'type_label', 'class_combo'], dtype='object')

# %% [markdown]
# Plot accuracy between validation data and train data

# %%
import matplotlib.pyplot as plt
def plot_learning_curve(train_loss, val_loss, train_metric, val_metric, metric_name='Accuracy'):
    plt.figure(figsize=(10,5))

    plt.subplot(1,2,1)
    plt.plot(train_loss, 'r--')
    plt.plot(val_loss, 'b--')
    plt.xlabel("epochs")
    plt.ylabel("Loss")
    plt.legend(['train', 'val'], loc='upper left')

    plt.subplot(1,2,2)
    plt.plot(train_metric, 'r--')
    plt.plot(val_metric, 'b--')
    plt.xlabel("epochs")
    plt.ylabel(metric_name)
    plt.legend(['train', 'val'], loc='upper left')

# %% [markdown]
# ### Model 1: Base Model - MLP Neural Network

# %% [markdown]
# This model is designed to take a 28x28 RGB image as input and predict two attributes of traffic signs simultaneously: their shape (among 5 categories) and type (among 16 categories). It utilizes shared layers for feature extraction and diverges into two separate paths for different classification tasks, enabling efficient learning of distinct yet related outputs.

# %%
# height = 28 pixel, width = 28 pixel
INPUT_DIM = (28,28,3)
HIDDEN_LAYER_DIM = 128
OUTPUT_CLASSES_SHAPE = 5  # Number of shape classes
OUTPUT_CLASSES_TYPE = 16  # Number of type classes

# %% [markdown]
# #### Install Keras

# %% [markdown]
# To build an image classifier we make use of Tensorflow‘ s Keras API to build our model

# %%
import tensorflow as tf
AUTOTUNE = tf.data.experimental.AUTOTUNE

tf.__version__
# Out:
# '2.15.0'

# %% [markdown]
# #### Set up the layers
# We will use the Sequential API to build models as it is the simplest. In a **Sequential** type, each layer takes the output from the previous layer and uses it as its input.
# **Dense** layers in a neural network mean that every node in one layer is connected to all the nodes in the previous layer.

# %%
# !pip install visualkeras
# Out:
# Requirement already satisfied: visualkeras in /usr/local/lib/python3.10/dist-packages (0.0.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.25.2)
# Requirement already satisfied: aggdraw>=1.3.11 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.3.18.post0)

# %% [markdown]
# # Baseline Model --- Traffic sign shape

# %%
model_shape_1 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=INPUT_DIM),
    tf.keras.layers.Dense(units=128, activation='relu', name='m1_hidden1'),
    tf.keras.layers.Dense(units=64, activation='relu', name='m1_hidden2'),
    tf.keras.layers.Dense(units=16, activation='relu', name='m1_hidden3'),
    tf.keras.layers.Dense(units=OUTPUT_CLASSES_SHAPE, activation='softmax', name='m1_output')
])

model_shape_1.compile(optimizer='adam',
                loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
                metrics=['categorical_accuracy'])

# %%
model_shape_1.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_12 (Flatten)        (None, 2352)              0
#
#  m1_hidden1 (Dense)          (None, 128)               301184
#
#  m1_hidden2 (Dense)          (None, 64)                8256
#
#  m1_hidden3 (Dense)          (None, 16)                1040
#
#  m1_output (Dense)           (None, 5)                 85
#
# =================================================================
# Total params: 310565 (1.18 MB)
# Trainable params: 310565 (1.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Generating the image for model architecture
visualkeras.layered_view(model_shape_1, scale_xy=2, scale_z=1, max_z=50, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=257x63>

# %%
tf.keras.utils.plot_model(model_shape_1, show_shapes=True)

# %% [markdown]
# ### Train the base model for shape
# - convert the class into string

# %%
train_data['shape_label'] = train_data['shape_label'].astype('str')
val_data['shape_label'] = val_data['shape_label'].astype('str')

train_data['type_label'] = train_data['type_label'].astype('str')
val_data['type_label'] = val_data['type_label'].astype('str')

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')
val_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

batch_size = 1000
#'image_path', 'shape_label', 'type_label'
train_generator = train_datagen.flow_from_dataframe(
        dataframe=train_data,
        directory='./',
        x_col="image_path",
        y_col="shape_label",
        target_size=(28, 28),
        batch_size=batch_size,
        class_mode='categorical')

validation_generator = val_datagen.flow_from_dataframe(
        dataframe=val_data,
        directory='./',
        x_col="image_path",
        y_col="shape_label",
        target_size=(28, 28),
        batch_size=batch_size,
        class_mode='categorical')
# Out:
# Found 2219 validated image filenames belonging to 5 classes.
# Found 740 validated image filenames belonging to 5 classes.

# %%
history = model_shape_1.fit_generator(train_generator, validation_data = validation_generator, epochs=100, verbose=0)
# Out:
# <ipython-input-283-d73befcce516>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model_shape_1.fit_generator(train_generator, validation_data = validation_generator, epochs=100, verbose=0)
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5575: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(

# %%
plot_learning_curve(history.history['loss'], history.history['val_loss'],
                    history.history['categorical_accuracy'], history.history['val_categorical_accuracy'],
                    metric_name='Accuracy')

# %% [markdown]
# # base model for traffic sign type

# %%
model_type_1 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=INPUT_DIM),
    tf.keras.layers.Dense(units=256, activation='relu', name='m1_hidden1'),
    tf.keras.layers.Dense(units=128, activation='relu', name='m1_hidden2'),
    tf.keras.layers.Dense(units=64, activation='relu', name='m1_hidden3'),
    tf.keras.layers.Dense(units=OUTPUT_CLASSES_TYPE, activation='softmax', name='m1_output')
])

model_type_1.compile(optimizer='adam',
                loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
                metrics=['categorical_accuracy'])

# %%
# Generating the image for model architecture
visualkeras.layered_view(model_type_1, scale_xy=2, scale_z=1, max_z=50, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=287x63>

# %%
#'image_path', 'shape_label', 'type_label'
train_generator_type = train_datagen.flow_from_dataframe(
        dataframe=train_data,
        directory='./',
        x_col="image_path",
        y_col="type_label",
        target_size=(28, 28),
        batch_size=batch_size,
        class_mode='categorical')

validation_generator_type = val_datagen.flow_from_dataframe(
        dataframe=val_data,
        directory='./',
        x_col="image_path",
        y_col="type_label",
        target_size=(28, 28),
        batch_size=batch_size,
        class_mode='categorical')
# Out:
# Found 2219 validated image filenames belonging to 16 classes.
# Found 740 validated image filenames belonging to 16 classes.

# %% [markdown]
# # train the model

# %%
history_type = model_type_1.fit_generator(train_generator_type, validation_data = validation_generator_type, epochs=100, verbose=0)
# Out:
# <ipython-input-288-ee86f0c76337>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_type = model_type_1.fit_generator(train_generator_type, validation_data = validation_generator_type, epochs=100, verbose=0)
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5575: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(

# %%
plot_learning_curve(history_type.history['loss'], history_type.history['val_loss'],
                    history_type.history['categorical_accuracy'], history_type.history['val_categorical_accuracy'],
                    metric_name='Accuracy')

# %% [markdown]
# # Baseline Model --- for both tasks

# %%
import visualkeras
model = tf.keras.Sequential([
    # Flatten the input to a 1D array
    tf.keras.layers.Flatten(input_shape=INPUT_DIM),
    # Dense layer with 256 neurons using sigmoid activation
    tf.keras.layers.Dense(HIDDEN_LAYER_DIM, activation='sigmoid'),
    # Add a dropout layer for regularization
    tf.keras.layers.Dropout(0.5),
    # Since we need two outputs, we can't directly use a single dense layer as the output layer.
    # We need a way to split the network here into two paths, each tailored to our class sizes.
    # For this, we will expand the model beyond the Sequential model capabilities.
])

# Adding two separate output layers
shape_output = tf.keras.layers.Dense(OUTPUT_CLASSES_SHAPE, activation='softmax', name='shape_output')(model.output)
type_output = tf.keras.layers.Dense(OUTPUT_CLASSES_TYPE, activation='softmax', name='type_output')(model.output)

# Creating a new model that includes both outputs
final_model = tf.keras.Model(inputs=model.input, outputs=[shape_output, type_output])

# %%
# Generating the image for model architecture
visualkeras.layered_view(final_model, scale_xy=2, scale_z=1, max_z=50, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=293x137>

# %% [markdown]
# * The initial layer in this network, **tf.keras.layers.Flatten**, converts the images from a two-dimensional array (28 by 28 pixels) into a one-dimensional array, totaling 2352 pixels (28 * 28 * 3)
# * Following the flattening process, the network employs a **tf.keras.layers.Dense layer**, which contains 256 neurons and utilises sigmoid activation. This fully connected layer is capable of learning intricate patterns from the flattened input data.
# * To enhance the model's generalisation capabilities and prevent overfitting, a **tf.keras.layers.Dropout** is incorporated next, setting approximately 50% of the neuron outputs to zero during training at random.
# * **Multi-output model**:
# the model diverges from a traditional sequential setup to accommodate dual outputs for classifying image data into multiple categories. At the end of the network:
#   - Shape Output: A dense layer with softmax activation predicts among 5 shape classes.
#   - Type Output: Another dense layer with softmax activation predicts among 16 type classes.
#
# * The final structure, final_model, integrates these outputs into one framework, enabling simultaneous prediction of both shape and type of traffic signs from single images.

# %%
final_model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  flatten_14_input (InputLay  [(None, 28, 28, 3)]          0         []
#  er)
#
#  flatten_14 (Flatten)        (None, 2352)                 0         ['flatten_14_input[0][0]']
#
#  dense_10 (Dense)            (None, 128)                  301184    ['flatten_14[0][0]']
#
#  dropout_7 (Dropout)         (None, 128)                  0         ['dense_10[0][0]']
#
#  shape_output (Dense)        (None, 5)                    645       ['dropout_7[0][0]']
#
#  type_output (Dense)         (None, 16)                   2064      ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 303893 (1.16 MB)
# Trainable params: 303893 (1.16 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(final_model, show_shapes=True)

# %% [markdown]
# ### Compile the model

# %%
# # update weight using Stochastic Gradient Descent (SGD)
# # use CategoricalCrossentropy because it is appropriate for classification task
# model.compile(optimizer='SGD',
#               loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
#               metrics=['categorical_accuracy'])

# %%
# Compile the model
final_model.compile(optimizer='adam',
                    loss={'shape_output': 'sparse_categorical_crossentropy',
                          'type_output': 'sparse_categorical_crossentropy'},
                    metrics=['accuracy'])

# %% [markdown]
# - We use ‘Adam’ optimiser because it is very efficient and needs low-memory (fast speed).
# - **sparse_categorical_crossentropy:** we use this loss function because our class labels for both shape and type are provided as integers (e.g., [0, 1, 2, 3, 4] for shapes and [0, 1, ..., 15] for types). It is used when the classes are encoded as integers, which is more memory efficient, especially for scenarios where the number of classes is quite large.

# %% [markdown]
# ### Train the model

# %% [markdown]
# Convert labels to be in string format for ImageDataGenerator

# %%
# Apply the 'assign_class_label' function to assign shape and type labels
train_data['Shape'], train_data['Type'] = zip(*train_data['image_path'].apply(assign_class_label))
val_data['Shape'], val_data['Type'] = zip(*val_data['image_path'].apply(assign_class_label))

# Convert classes to strings if not already
train_data['Shape'] = train_data['Shape'].astype('str')
train_data['Type'] = train_data['Type'].astype('str')
val_data['Shape'] = val_data['Shape'].astype('str')
val_data['Type'] = val_data['Type'].astype('str')

# %%
from sklearn.preprocessing import LabelEncoder

# Encode Shape and Type labels
shape_encoder = LabelEncoder()
type_encoder = LabelEncoder()

train_data['Shape'] = shape_encoder.fit_transform(train_data['Shape'])
val_data['Shape'] = shape_encoder.transform(val_data['Shape'])

train_data['Type'] = type_encoder.fit_transform(train_data['Type'])
val_data['Type'] = type_encoder.transform(val_data['Type'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Data generators
train_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')
val_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

batch_size = 32

# Modify generators to handle two types of labels
train_generator = train_datagen.flow_from_dataframe(
        dataframe=train_data,
        directory='./',
        x_col="image_path",
        y_col=["Shape", "Type"],  # Two columns for y_col
        target_size=(28, 28),  # Ensure target size matches the input size of the network
        batch_size=batch_size,
        class_mode='multi_output')

validation_generator = val_datagen.flow_from_dataframe(
        dataframe=val_data,
        directory='./',
        x_col="image_path",
        y_col=["Shape", "Type"],  # Two columns for y_col
        target_size=(28, 28),  # Ensure target size matches the input size of the network
        batch_size=batch_size,
        class_mode='multi_output')
# Out:
# Found 2219 validated image filenames.
# Found 740 validated image filenames.

# %%
# from tensorflow.keras.preprocessing.image import ImageDataGenerator

# # Data generators
# # Training generator with image augmentation
# train_datagen = ImageDataGenerator(
#     rescale=1./255,
#     rotation_range=40,        # Random rotations from 0 to 40 degrees
#     width_shift_range=0.2,    # Random horizontal shifts up to 20% of the image width
#     height_shift_range=0.2,   # Random vertical shifts up to 20% of the image height
#     shear_range=0.2,          # Shear transformation
#     zoom_range=0.2,           # Random zoom up to 20%
#     horizontal_flip=True,     # Random horizontal flips
#     fill_mode='nearest',      # Strategy for filling in newly created pixels
#     data_format='channels_last'
# )

# # Validation generator without augmentation, only rescaling
# val_datagen = ImageDataGenerator(
#     rescale=1./255,
#     data_format='channels_last'
# )

# batch_size = 32

# # Modify generators to handle two types of labels
# train_generator = train_datagen.flow_from_dataframe(
#         dataframe=train_data,
#         directory='./',
#         x_col="image_path",
#         y_col=["Shape", "Type"],  # Two columns for y_col
#         target_size=(28, 28),  # Ensure target size matches the input size of the network
#         batch_size=batch_size,
#         class_mode='multi_output')

# validation_generator = val_datagen.flow_from_dataframe(
#         dataframe=val_data,
#         directory='./',
#         x_col="image_path",
#         y_col=["Shape", "Type"],  # Two columns for y_col
#         target_size=(28, 28),  # Ensure target size matches the input size of the network
#         batch_size=batch_size,
#         class_mode='multi_output')

# %% [markdown]
# #### Data Augmentation

# %% [markdown]
# The ImageDataGenerator module in Keras enhances dataset diversity through transformations such as shifts, zoom, shear, and rotation. This augmentation improves model robustness and reduces overfitting by simulating real-world variations.

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Fetch an original image from the dataset
# original_images, _ = next(train_generator)  # Reset to get the first image consistently
# original_image = original_images[0]

# # Create separate generators for each specific augmentation to control and demonstrate each one
# augmentations = {
#     'Rotation (40°)': ImageDataGenerator(rotation_range=40),
#     'Width Shift (20%)': ImageDataGenerator(width_shift_range=0.2),
#     'Height Shift (20%)': ImageDataGenerator(height_shift_range=0.2),
#     'Shear (20%)': ImageDataGenerator(shear_range=0.2),
#     'Zoom (20%)': ImageDataGenerator(zoom_range=0.2),
#     'Horizontal Flip': ImageDataGenerator(horizontal_flip=True)
# }

# # Display the original image and each augmentation
# fig, axes = plt.subplots(1, len(augmentations) + 1, figsize=(20, 3))
# axes = axes.flatten()

# # Show the original image first
# axes[0].imshow(original_image)
# axes[0].axis('off')
# axes[0].set_title('Original Image')

# # Apply each augmentation and display the result
# for i, (desc, gen) in enumerate(augmentations.items(), start=1):
#     # Generate augmented image
#     # Must expand dimension of original_image to fit the generator input requirement
#     aug_image = gen.flow(np.expand_dims(original_image, 0), batch_size=1).next()[0]
#     axes[i].imshow(aug_image)
#     axes[i].axis('off')
#     axes[i].set_title(desc)

# plt.tight_layout()
# plt.show()

# %%
# history = model.fit_generator(train_generator, validation_data = validation_generator, epochs=50, verbose=0)

# %%
# Ensure to use 'final_model' for training with the correct input and output layers
history = final_model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=50,
    verbose=0
)

# %%
def plot_learning_curve(loss, val_loss, shape_acc, type_acc, val_shape_acc, val_type_acc):
    import matplotlib.pyplot as plt
    epochs = range(1, len(loss) + 1)

    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss, 'bo-', label='Training Loss')
    plt.plot(epochs, val_loss, 'ro-', label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, shape_acc, 'bo-', label='Training Shape Accuracy')
    plt.plot(epochs, type_acc, 'b--', label='Training Type Accuracy')
    plt.plot(epochs, val_shape_acc, 'ro-', label='Validation Shape Accuracy')
    plt.plot(epochs, val_type_acc, 'r--', label='Validation Type Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Now use the function with correct keys
plot_learning_curve(history.history['loss'], history.history['val_loss'],
                    history.history['shape_output_accuracy'], history.history['type_output_accuracy'],
                    history.history['val_shape_output_accuracy'], history.history['val_type_output_accuracy'])

# %% [markdown]
# *Observation*
# - As the model trains through more epochs, we see a decrease in loss and an increase in accuracy. This means the model is effectively learning from the training data and getting better at correctly classifying the traffic signs into their respective shapes and types. The graphs show that both the training and validation losses drop significantly as the model trains, and the accuracy for identifying shapes and types increases. The training accuracy is slightly higher than the validation accuracy, but since they're close and follow a similar trend, it doesn't indicate serious overfitting. This small gap between the training and validation results is normal and shows that the model is learning well and can handle new, unseen data effectively.

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'shape_output_loss', 'type_output_loss', 'shape_output_accuracy', 'type_output_accuracy', 'val_loss', 'val_shape_output_loss', 'val_type_output_loss', 'val_shape_output_accuracy', 'val_type_output_accuracy'])

# %%
# Average training accuracy
avg_training_accuracy = sum(history.history['shape_output_accuracy']) / len(history.history['shape_output_accuracy'])

# Average validation accuracy
avg_validation_accuracy = sum(history.history['val_shape_output_accuracy']) / len(history.history['val_shape_output_accuracy'])

print(f"Average Shape Training Accuracy: {avg_training_accuracy*100:.2f}%")
print(f"Average Shape Validation Accuracy: {avg_validation_accuracy*100:.2f}%")
# Out:
# Average Shape Training Accuracy: 93.86%
# Average Shape Validation Accuracy: 94.70%

# %%
# Average training accuracy for Type output
avg_training_accuracy_type = sum(history.history['type_output_accuracy']) / len(history.history['type_output_accuracy'])

# Average validation accuracy for Type output
avg_validation_accuracy_type = sum(history.history['val_type_output_accuracy']) / len(history.history['val_type_output_accuracy'])

print(f"Average Type Training Accuracy: {avg_training_accuracy_type*100:.2f}%")
print(f"Average Type Validation Accuracy: {avg_validation_accuracy_type*100:.2f}%")
# Out:
# Average Type Training Accuracy: 89.91%
# Average Type Validation Accuracy: 89.82%

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'shape_output_loss', 'type_output_loss', 'shape_output_accuracy', 'type_output_accuracy', 'val_loss', 'val_shape_output_loss', 'val_type_output_loss', 'val_shape_output_accuracy', 'val_type_output_accuracy'])

# %%
# Assuming 'history' is the variable holding the training history
# Replace 'shape_output_accuracy' and 'val_shape_output_accuracy' with your actual metric names if they are different

# Maximum training accuracy
max_training_accuracy = max(history.history['shape_output_accuracy'])  # or 'type_output_accuracy' as applicable
max_training_epoch = history.history['shape_output_accuracy'].index(max_training_accuracy)

# Maximum validation accuracy
max_validation_accuracy = max(history.history['val_shape_output_accuracy'])  # or 'val_type_output_accuracy' as applicable
max_validation_epoch = history.history['val_shape_output_accuracy'].index(max_validation_accuracy)

print(f"Maximum Training Accuracy: {max_training_accuracy*100:.2f}% at epoch {max_training_epoch+1}")
print(f"Maximum Validation Accuracy: {max_validation_accuracy*100:.2f}% at epoch {max_validation_epoch+1}")
# Out:
# Maximum Training Accuracy: 98.83% at epoch 45
# Maximum Validation Accuracy: 97.57% at epoch 35

# %%
# Assuming 'history' is the variable holding the training history
# Replace 'type_output_accuracy' and 'val_type_output_accuracy' with your actual metric names if they are different

# Maximum training accuracy for Type
max_type_training_accuracy = max(history.history['type_output_accuracy'])  # Use the correct key for type accuracy
max_type_training_epoch = history.history['type_output_accuracy'].index(max_type_training_accuracy)

# Maximum validation accuracy for Type
max_type_validation_accuracy = max(history.history['val_type_output_accuracy'])  # Use the correct key for type validation accuracy
max_type_validation_epoch = history.history['val_type_output_accuracy'].index(max_type_validation_accuracy)

print(f"Maximum Training Type Accuracy: {max_type_training_accuracy*100:.2f}% at epoch {max_type_training_epoch+1}")
print(f"Maximum Validation Type Accuracy: {max_type_validation_accuracy*100:.2f}% at epoch {max_type_validation_epoch+1}")
# Out:
# Maximum Training Type Accuracy: 97.61% at epoch 48
# Maximum Validation Type Accuracy: 94.32% at epoch 43

# %% [markdown]
# ### Incremental changes

# %%
# Drop-out?

# %% [markdown]
# ## Testing the final model

# %%
# # Data generator for test data
# test_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

# batch_size = 1

# test_generator = test_datagen.flow_from_dataframe(
#         dataframe=test_data,
#         directory='./',
#         x_col="image_path",
#         y_col=["Shape", "Type"],  # Assuming you want to predict both Shape and Type
#         target_size=(32, 32),
#         batch_size=batch_size,
#         class_mode='multi_output')  # Set to 'multi_output' to match your model's configuration

# %%
# # Data generator for test data
# test_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

# batch_size = 32  # or any batch size that fits your memory constraints

# test_generator = test_datagen.flow_from_dataframe(
#         dataframe=test_data,
#         directory='./',
#         x_col="image_path",
#         y_col=["Shape", "Type"],  # Assuming you want to predict both Shape and Type
#         target_size=(28, 28),  # Ensure target size matches the input size of the network
#         batch_size=batch_size,
#         class_mode='multi_output')  # Set to 'multi_output' to match your model's configuration

# # Evaluate the model
# final_model.evaluate(test_generator)

# %% [markdown]
# The evaluation results show that the model performs well in predicting shapes with an accuracy of 97.16%. However, its accuracy in predicting types is notably lower at 7.43%. This indicates a need for improvement in the model's ability to predict types accurately.

# %% [markdown]
# ## Ploting some results

# %%
# ## still wrong

# import matplotlib.pyplot as plt
# import numpy as np

# # Increase the figure size and font size for better visibility
# plt.figure(figsize=(20, 5))  # Adjust the figure size as needed
# font = {'family' : 'serif',
#         'weight' : 'bold',
#         'size'   : 12}  # Increase font size for better readability
# plt.rc('font', **font)

# batches = 0
# for x, y in test_generator:
#     batches += 1
#     y_hat = final_model.predict(x, verbose=0)
#     x = np.squeeze(x)
#     if batches < 5:
#         plt.subplot(1, 5, batches)
#         plt.imshow(x[0])  # Displaying the first image in the batch
#         shape_pred_index = np.argmax(y[0])
#         type_pred_index = np.argmax(y_hat[1])
#         try:
#             shape_label = shapes_inv[shape_pred_index]
#         except KeyError:
#             shape_label = 'Unknown Shape'
#         try:
#             type_label = types_inv[type_pred_index]
#         except KeyError:
#             type_label = 'Unknown Type'
#         plt.title("Actual-{}, Pred-{}".format(shape_label, type_label), pad=20)  # Add padding to avoid overlap
#     else:
#         break

#     plt.axis('off')
# plt.tight_layout()  # Adjust layout to fit everything nicely
# plt.show()

# %%
# Deeper network: it may be the old term of deap learning
# Residual Network: A residual neural network is a seminal deep learning model in which the weight layers learn residual functions with reference to the layer inputs.
# Transfer Learning: will be taught in week 8

# %% [markdown]
# # Model 2 Advanced Model: CNN model

# %% [markdown]
# - Pros:
# 1.   Scalabiity with data, good for big dataset, improve performace with more data
# 2.   List item
#
#
# - Cons:
#
#
# 1.   Less powerful on smaller dataset
# 2.   List item

# %%
# # CNN model
# # Lenet Model - the classic CNN architecture

# from keras.models import Sequential
# from keras.layers import Conv2D, Activation, MaxPooling2D, Flatten, Dense, Dropout
# from keras import optimizers, regularizers
# from keras.callbacks import LearningRateScheduler
# import numpy as np

#   def model_cnn():
#   # use Sequential to create a linear stack of layers which means each layer has exact one input tensor and one output tensor.
#   model_cnn = Sequential()

#   # First Convolutional Block

#   # create 32 filters (kernels) that each have a 3x3 size
#   # add L2 regularization to penalize large weights, which helps prevent
#   # overfitting by ensuring simpler models.
#   model_cnn.add(Conv2D(32, (3, 3), kernel_regularizer=regularizers.l2(0.001), input_shape=(28, 28, 3)))
#   # add ReLU (rectified linear unit) is a non-linear activation function used to
#   # introduce non-linearity in the model, allowing it to learn more complex patterns
#   model_cnn.add(Activation('relu'))
#   # This layer reduces the spatial dimensions (height and width) of the input
#   # feature maps by taking the maximum value over a 2x2 pooling window.
#   # This helps reduce computation and controls overfitting by providing
#   # an abstracted form of the feature maps.
#   model_cnn.add(MaxPooling2D(pool_size=(2, 2)))
#   #-------------------------------------------------------------------------------
#   # Second Convolutional Block
#   # Similar to the first block but with 64 filters. Increasing the number of filters in deeper layers allows the network to capture more complex patterns.
#   model_cnn.add(Conv2D(64, (3, 3)))
#   model_cnn.add(Activation('relu'))
#   model_cnn.add(MaxPooling2D(pool_size=(2, 2)))
#   #-------------------------------------------------------------------------------
#   # Flattening Layer
#   # This layer converts 3D feature maps to 1D feature vectors
#   # Flattens the 3D output of the previous layer into a 1D array to be used as input to the fully connected layers.
#   model_cnn.add(Flatten())  # This converts 3D feature maps to 1D feature vectors
#   #-------------------------------------------------------------------------------
#   # Fully Connected Layers
#   # Dense(64): A fully connected layer with 64 neurons.
#   # Dropout(0.5): Randomly sets the output features of 50% of the neurons to zero.
#   # This helps in reducing overfitting by preventing complex co-adaptations on training data.
#   # Dense(4): A fully connected layer with 4 neurons, one for each class assuming a 4-class classification problem.
#   # Activation('softmax'): Softmax activation function is used in the output layer for multi-class classification.
#   # It outputs the probabilities of the input being in each class.
#   model_cnn.add(Dense(64))
#   model_cnn.add(Activation('relu'))
#   model_cnn.add(Dropout(0.5))
#   model_cnn.add(Dense(4))
#   model_cnn.add(Activation('softmax'))

#   # Setting up the optimizer
#   # optimizers.SGD(...): Configures the model with the stochastic gradient descent (SGD) optimizer.
#   # lr is learning rate, decay is the rate at which the learning rate decreases,
#   # momentum helps accelerate gradients vectors in the right directions,
#   # thus leading to faster converging, and nesterov=True is an improved version of the momentum method.
#   # model_cnn.compile(...): Prepares the model for training.
#   # It specifies the loss function and the metrics to be evaluated during training and testing.

#   # Define a learning rate decay function
#   def lr_schedule(epoch):
#       initial_lr = 0.01
#       decay = 1e-6
#       lr = initial_lr / (1 + decay * epoch)
#       return lr

#   # Initialize the optimizer with the new learning rate parameter
#   sgd = optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True)

#   # Compile the model with the new optimizer
#   model_cnn.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['categorical_accuracy'])

#   # Add Learning Rate Scheduler to callbacks
#   callbacks_list = [LearningRateScheduler(lr_schedule)]
#    return model

# %% [markdown]
# # Lenet

# %% [markdown]
# Simple representation of the layers in a LeNet-like architecture:

# %% [markdown]
# Input -> Convolutional Layer -> Pooling Layer -> Convolutional Layer -> Pooling Layer -> Fully Connected Layer -> Fully Connected Layer -> Output

# %%
from keras.models import Sequential
from keras.layers import Conv2D, Activation, MaxPooling2D, Flatten, Dense, Dropout
from keras import optimizers, regularizers
from keras.callbacks import LearningRateScheduler

def model_lenet():
    # Create a linear stack of layers using Sequential
    model_lenet = Sequential()

    # First Convolutional Block
    model_lenet.add(Conv2D(32, (3, 3), kernel_regularizer=regularizers.l2(0.001), input_shape=(28, 28, 3)))
    model_lenet.add(Activation('relu'))
    model_lenet.add(MaxPooling2D(pool_size=(2, 2)))

    # Second Convolutional Block
    model_lenet.add(Conv2D(64, (3, 3)))
    model_lenet.add(Activation('relu'))
    model_lenet.add(MaxPooling2D(pool_size=(2, 2)))

    # Flattening Layer
    model_lenet.add(Flatten())

    # Fully Connected Layers
    model_lenet.add(Dense(64))
    model_lenet.add(Activation('relu'))
    model_lenet.add(Dropout(0.5))
    model_lenet.add(Dense(4))
    model_lenet.add(Activation('softmax'))

    # Setting up the optimizer
    sgd = optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True)

    # Define a learning rate decay function
    def lr_schedule(epoch):
        initial_lr = 0.01
        decay = 1e-6
        lr = initial_lr / (1 + decay * epoch)
        return lr

    # Compile the model with the optimizer
    model_lenet.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['categorical_accuracy'])

    # Add Learning Rate Scheduler to callbacks
    callbacks_list = [LearningRateScheduler(lr_schedule)]

    return model

# %%
# Generating the image for model architecture
visualkeras.layered_view(model_lenet, scale_xy=2, scale_z=1, max_z=50, legend=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-324-f9cb4773fc56> in <cell line: 2>()
#       1 # Generating the image for model architecture
# ----> 2 visualkeras.layered_view(model_lenet, scale_xy=2, scale_z=1, max_z=50, legend=True)
#
# /usr/local/lib/python3.10/dist-packages/visualkeras/layered.py in layered_view(model, to_file, min_z, min_xy, max_z, max_xy, scale_z, scale_xy, type_ignore, index_ignore, color_map, one_dim_orientation, background_fill, draw_volume, padding, spacing, draw_funnel, shade_step, legend, font, font_color)
#      63         color_map = dict()
#      64
# ---> 65     for index, layer in enumerate(model.layers):
#      66
#      67         # Ignore layers that the use has opted out to
#
# AttributeError: 'function' object has no attribute 'layers'

# %% [markdown]
# Observations:

# %%
model = model_cnn()
print(model.summary())
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 26, 26, 32)        896
#
#  activation_12 (Activation)  (None, 26, 26, 32)        0
#
#  max_pooling2d_6 (MaxPoolin  (None, 13, 13, 32)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 11, 11, 64)        18496
#
#  activation_13 (Activation)  (None, 11, 11, 64)        0
#
#  max_pooling2d_7 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  flatten_15 (Flatten)        (None, 1600)              0
#
#  dense_11 (Dense)            (None, 64)                102464
#
#  activation_14 (Activation)  (None, 64)                0
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_12 (Dense)            (None, 4)                 260
#
#  activation_15 (Activation)  (None, 4)                 0
#
# =================================================================
# Total params: 122116 (477.02 KB)
# Trainable params: 122116 (477.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
history = model.fit_generator(train_generator, validation_data = validation_generator, epochs=50, verbose=0)
# Out:
# <ipython-input-340-243f5d5117d3>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator, validation_data = validation_generator, epochs=50, verbose=0)
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-340-243f5d5117d3> in <cell line: 1>()
# ----> 1 history = model.fit_generator(train_generator, validation_data = validation_generator, epochs=50, verbose=0)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2911             stacklevel=2,
#    2912         )
# -> 2913         return self.fit(
#    2914             generator,
#    2915             steps_per_epoch=steps_per_epoch,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node categorical_crossentropy/softmax_cross_entropy_with_logits defined at (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#
#   File "/usr/local/lib/python3.10/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelapp.py", line 619, in start
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/platform/asyncio.py", line 195, in start
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 685, in <lambda>
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 738, in _run_callback
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 825, in inner
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 786, in run
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 361, in process_one
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 261, in dispatch_shell
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 539, in execute_request
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py", line 302, in do_execute
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 539, in run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#
#   File "<ipython-input-340-243f5d5117d3>", line 1, in <cell line: 1>
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2913, in fit_generator
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1807, in fit
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1401, in train_function
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1384, in step_function
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1373, in run_step
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1151, in train_step
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1209, in compute_loss
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/compile_utils.py", line 277, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/losses.py", line 143, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/losses.py", line 270, in call
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/losses.py", line 2221, in categorical_crossentropy
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/backend.py", line 5579, in categorical_crossentropy
#
# logits and labels must be broadcastable: logits_size=[1000,4] labels_size=[1000,5]
# 	 [[{{node categorical_crossentropy/softmax_cross_entropy_with_logits}}]] [Op:__inference_train_function_230101]

# %%
plot_learning_curve(history.history['loss'], history.history['val_loss'],
                    history.history['categorical_accuracy'], history.history['val_categorical_accuracy'],
                    metric_name='Accuracy')

# %% [markdown]
# Visually Interpreting the CNN's Inner Layers

# %% [markdown]
# We examine the internal layers of the CNN model to gain insights and interpret the significance of the features that the model identified while classifying a traffic sign

# %% [markdown]
# Display prediction result

# %% [markdown]
# show green color when correct & red when incorrect Actual Vs Predicted

# %% [markdown]
# # VGG

# %% [markdown]
# ## shape

# %%
# height = 28 pixel, width = 28 pixel
INPUT_DIM = (28,28,3)
HIDDEN_LAYER_DIM = 128
OUTPUT_CLASSES_SHAPE = 5  # Number of shape classes
OUTPUT_CLASSES_TYPE = 16  # Number of type classes

# %%
import tensorflow as tf


model_VGG_1 = tf.keras.Sequential([
    #VGG block 1
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(28, 28, 3)),
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D((2, 2)),

    #VGG block 2
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D((2, 2)),

    #VGG block 3
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D((2, 2)),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(OUTPUT_CLASSES_SHAPE),
])

# %%
# Generating the image for model architecture
visualkeras.layered_view(model_VGG_1, scale_xy=2, scale_z=1, max_z=50, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=659x111>

# %%
model_VGG_1.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=['categorical_accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')
val_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

batch_size = 1000
#'image_path', 'shape_label', 'type_label'
train_generator = train_datagen.flow_from_dataframe(
        dataframe=train_data,
        directory='./',
        x_col="image_path",
        y_col="shape_label",
        target_size=(28, 28),
        batch_size=batch_size,
        class_mode='categorical')

validation_generator = val_datagen.flow_from_dataframe(
        dataframe=val_data,
        directory='./',
        x_col="image_path",
        y_col="shape_label",
        target_size=(28, 28),
        batch_size=batch_size,
        class_mode='categorical')
# Out:
# Found 2219 validated image filenames belonging to 5 classes.
# Found 740 validated image filenames belonging to 5 classes.

# %%
history_VGG_1 = model_VGG_1.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=25,
    verbose=0
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-341-1ad4bb3856e9> in <cell line: 1>()
# ----> 1 history_VGG_1 = model_VGG_1.fit(
#       2     train_generator,
#       3     validation_data=validation_generator,
#       4     epochs=25,
#       5     verbose=0
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1817                 logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1818                 if logs is None:
# -> 1819                     raise ValueError(
#    1820                         "Unexpected result of `train_function` "
#    1821                         "(Empty logs). This could be due to issues in input "
#
# ValueError: Unexpected result of `train_function` (Empty logs). This could be due to issues in input pipeline that resulted in an empty dataset. Otherwise, please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.

# %% [markdown]
# ## Type

# %%
import tensorflow as tf


model_VGG_2 = tf.keras.Sequential([
    #VGG block 1
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(28, 28, 3)),
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D((2, 2)),

    #VGG block 2
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D((2, 2)),

    #VGG block 3
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D((2, 2)),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(OUTPUT_CLASSES_TYPE),
])

# %%
# Generating the image for model architecture
visualkeras.layered_view(model_VGG_2, scale_xy=2, scale_z=1, max_z=50, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=659x111>

# %%
model_VGG_2.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=['categorical_accuracy'])

# %%
history_VGG_2 = model_VGG_2.fit_generator(train_generator, validation_data = validation_generator, epochs=25, verbose=0)
# Out:
# <ipython-input-335-580fe2e67df4>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_VGG_2 = model_VGG_2.fit_generator(train_generator, validation_data = validation_generator, epochs=25, verbose=0)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-335-580fe2e67df4> in <cell line: 1>()
# ----> 1 history_VGG_2 = model_VGG_2.fit_generator(train_generator, validation_data = validation_generator, epochs=25, verbose=0)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2911             stacklevel=2,
#    2912         )
# -> 2913         return self.fit(
#    2914             generator,
#    2915             steps_per_epoch=steps_per_epoch,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1401, in train_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1384, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1373, in run_step  **
#         outputs = model.train_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1151, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1209, in compute_loss
#         return self.compiled_loss(
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/compile_utils.py", line 277, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/losses.py", line 143, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/losses.py", line 270, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/losses.py", line 2221, in categorical_crossentropy
#         return backend.categorical_crossentropy(
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/backend.py", line 5573, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (None, 1) and (None, 16) are incompatible

# %% [markdown]
# # Conclusion

# %% [markdown]
# MLPs serve as a practical baseline for tasks like traffic sign classification due to their straightforward implementation and quick training. They are capable of modelling interactions between all input features, which is crucial for recognising complex patterns in the dataset. However, they are typically less effective than Convolutional Neural Networks (CNNs) for processing image data, as CNNs excel at capturing spatial hierarchies through their convolutional layers. This is evident from comparison tables where CNNs consistently show lower loss and higher accuracy.
# In conclusion, we think Model 2 (CNN) is superior.

# %% [markdown]
# # References

# %% [markdown]
# - https://www.linkedin.com/pulse/classify-traffic-signs-deep-learning-james-medel/
# - https://github.com/james94/P3-Traffic-Sign-Classifier-CarND/blob/master/Traffic_Sign_Classifier_with_LeNet.ipynb
# - https://www.youtube.com/watch?v=jztwpsIzEGc
